# %% [markdown]
# # Table of Content:
#
# - <a href = "#load">1. Loading Datasets </a>
# - <a href = "#understand">2. Understanding the Data </a>
# - <a href = "#prep">3. Preprocessing the data:</a>
#     - <a href = "#idc">3.1 Removing ID Column from the dataset</a>
#     - <a href = "#merge">3.2 Merging the two datasets </a>
#     - <a href = "#types">3.3 Columns' Types </a>
#     - <a href = "#miss">3.4 Missing Data </a>
#     - <a href = "#stat">3.5 Statistical Analysis: </a>
#         - <a href = "#desc">3.5.1 Descriptive Analysis: </a>
#             - <a href = "#num">3.5.1.1 Numerical Features Analysis </a>
#             - <a href = "#cat">3.5.1.2 Categorical Features Analysis </a>
#                 - <a href = "#vin">3.5.1.2.1 Removing Duplicate Vins </a>
#                 - <a href = "#statn">3.5.1.2.2 Handling States' names </a>
#                 - <a href = "#up">3.5.1.2.3 Uppercase the other Columns </a>
#                 - <a href = "#divi">3.5.1.2.4 Dividing into Old and New sets </a>
#                 - <a href = "#exc">3.5.1.2.5 Excluding relatively not used cars </a>
#                 - <a href = "#vin2">3.5.1.2.6 Removing Vin Column </a>
# - <a href = "#feat">4. Feature Engineering:</a>
#     - <a href = "#feat1">4.1 Car Usage Levels</a>
#     - <a href = "#feat2">4.2 City Importance</a>
#     - <a href = "#feat3">4.3 Added Features Plotting</a>
# - <a href = "#answer">5Answering Questions:</a>
#     - <a href = "#q1">5.1 Is the distribution of the offered cars differs from the new and old ones according to the city of the seller? </a>
#     - <a href = "#q2">5.2 Is the distribution of the offered cars differs from the new and old ones according to the State of the seller? </a>
#     - <a href = "#q3">5.3 Is There is any differences in the Price between the old and the new cars? </a>
#     - <a href = "#q4">5.4 The Price of the car affected by the State of the seller ? </a>
#     - <a href = "#q5">5.5 How the Prices of the cars are changed according to the year of manufacturing? </a>
#     - <a href = "#q6">5.6 There is any relation between the Year and the Milage? </a>
#     - <a href = "#q7">5.7 What is the distribution of the cars in the market? </a>
#     - <a href = "#q8">5.8 How the Price of a certain brand cars' changes according the year of manufacturing? </a>
#     - <a href = "#q9">5.9 Is there is any relationship between Mileage, Year and Price? </a>
# - <a href = "#div2">6. Dividing and Saving data </a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <span id="load"></span>
# # 1- Loading the two Datasets:

# %%
df1 = pd.read_csv("tc20171021.csv",on_bad_lines='skip')
df2 = pd.read_csv("true_car_listings.csv")

# %%
df1.head()
# Out:
#    Id  Price  Year  Mileage            City State                Vin   Make  \
# 0   1  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1   2  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2   3  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3   4  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4   5  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %%
df2.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %% [markdown]
# <span id="understand"></span>
# # 2- Understanding the data:
#
# ![image.png](30f5dd06-3df5-436b-abf9-9e3cc985382d.jpeg)
#
# The dataset contains information about used cars that was presented for sale on TrueCar.com and the data icludes 8 Column as Follows:
# - Price   : Price in dollars of the used car, this will be our target
# - Year    : The year when the Car was manufactured
# - Mileage : Number of miles that the car has made and this represents the usage density of the car
# - City    : The City of the Seller
# - State   : The State of the seller
# - Vin     : Veighcle Identity number and this is a unque key for the car
# - Make    : Manufacturer name
# - Model   : Model of the Car

# %% [markdown]
# <span id="prep"></span>
# # 3- Preprocessing:

# %% [markdown]
# <span id="idc"></span>
# ## 3.1: Dropping the ID Column form one set

# %%
df1.drop(columns = ["Id"], inplace = True)

# %%
df1.head()
# Out:
#    Price  Year  Mileage            City State                Vin   Make  \
# 0  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %% [markdown]
# <span id="merge"></span>
# ## 3.2 Merging the two datasets:

# %%
df_full = pd.concat([df1, df2], ignore_index=True)

# %%
df_full
# Out:
#          Price  Year  Mileage            City State                Vin   Make  \
# 0        16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1        15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2        16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3        15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4        16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
# ...        ...   ...      ...             ...   ...                ...    ...
# 2068367  63215  2017        9     Culver City    CA  YV1A22MK9H1013237  Volvo
# 2068368  72260  2017     3201       Englewood    NJ  YV4A22PL3H1186162  Volvo
# 2068369  55999  2016    28941    Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 2068370  60240  2017     3005     San Leandro    CA  YV4A22NLXH1006162  Volvo
# 2068371  76995  2017     2502        New York    NY  YV4BC0ZX1H1109845  Volvo
#
#                      Model
# 0        EncoreConvenience
# 1                EncoreFWD
# 2            EncoreLeather
# 3                EncoreFWD
# 4        EncoreConvenience
# ...                    ...
# 2068367              S90T6
# 2068368             XC90T6
# 2068369            XC90AWD
# 2068370                V90
# 2068371             XC90T8
#
# [2068372 rows x 8 columns]

# %% [markdown]
# <span id="types"></span>
# ## 3.3 Columns' Data Types:

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068372 entries, 0 to 2068371
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   Price    int64
#  1   Year     int64
#  2   Mileage  int64
#  3   City     object
#  4   State    object
#  5   Vin      object
#  6   Make     object
#  7   Model    object
# dtypes: int64(3), object(5)
# memory usage: 126.2+ MB

# %% [markdown]
# Three numerical and 5 Categorical data

# %% [markdown]
# <span id="miss"></span>
#
# ## 3.4 Missing Data:

# %%
df_full.isna().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %% [markdown]
# <span id="stat"></span>
#
# ## 3.5 Statistical Analysis:

# %% [markdown]
# <span id="desc"></span>
# ### 3.5.1 Descriptive Analysis:

# %% [markdown]
# <span id="num"></span>
#
# #### 3.5.1.1 Numerical Columns:

# %%
for i in df_full.columns.to_list():
    if str(df_full[i].dtype) == 'int64':
        # Print Statistics of it
        print("Descriptive Statistics is for columns {} :\n {}".format(i, df_full[i].describe()))
        fig, ax = plt.subplots(2,1, figsize = (10,10))
        ax[0].set_title(f"Box Plot For Columns {i}")
        ax[0].boxplot(df_full[i], vert = False, sym = "r.")
        ax[1].set_title(f"Histogram of values for column {i}")
        r = ax[1].hist(df_full[i], histtype = "bar")
        ax[1].set_ylim(top = np.max(r[0]) + 10)
        plt.show()
# Out:
# Descriptive Statistics is for columns Price :
#  count    2.068372e+06
# mean     2.117289e+04
# std      1.334331e+04
# min      1.500000e+03
# 25%      1.299500e+04
# 50%      1.800000e+04
# 75%      2.681700e+04
# max      4.995000e+05
# Name: Price, dtype: float64
# Descriptive Statistics is for columns Year :
#  count    2.068372e+06
# mean     2.013300e+03
# std      3.430814e+00
# min      1.997000e+03
# 25%      2.012000e+03
# 50%      2.014000e+03
# 75%      2.016000e+03
# max      2.018000e+03
# Name: Year, dtype: float64
# Descriptive Statistics is for columns Mileage :
#  count    2.068372e+06
# mean     5.274318e+04
# std      6.836142e+04
# min      5.000000e+00
# 25%      2.391000e+04
# 50%      4.042300e+04
# 75%      7.250400e+04
# max      7.758776e+07
# Name: Mileage, dtype: float64

# %% [markdown]
# - <b>For The Prices Column:</b>
# It seams that most of the prices are between 0 and 100k dollars which is reasonable as they have to be cheper than the new cars.
# - <b>For the Year Column: </b>
# Most of the cars that was offered in the website is manufactured between the year of 2006 and 2018 but there some care are older than that, so we expect their behavior to be slightly different form those relatively new cars.
# - <b> For the Mileage Column: </b>
# We can expect that there some correlation between the column of Year and the column of Mileage but from the above figures it appears that there some cars that has very large mileage so we can consider these as outliers and the next step is to handle this issue.

# %% [markdown]
# <span id="del"></span>
#
# ##### 3.5.1.1.1 Detection and removal of Mileage outliers:

# %%
# Removig outliers in milage columns using the 1.5 inter quartile range
mile_iqr    = (df_full["Mileage"].describe()["75%"] - df_full["Mileage"].describe()["25%"])
mile_iqr_15 = 1.5*mile_iqr
mile_iqr_3  = 3*mile_iqr
# Inner and outer  Lower fences:
#lower_inner = df_full["Mileage"].describe()["25%"] - mile_iqr_15
#lower_outer = df_full["Mileage"].describe()["25%"] - mile_iqr_3
# Inner and outer  Upper fences:
#upper_inner = df_full["Mileage"].describe()["75%"] + mile_iqr_15
#upper_outer = df_full["Mileage"].describe()["75%"] + mile_iqr_3
# Severe Outlies are those points which not between the two outer:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3060/1912080348.py in <module>
#       1 # Removig outliers in milage columns using the 1.5 inter quartile range
# ----> 2 mile_iqr    = (df_full["Mileage"].describe()["75%"] - df_full["Mileage"].describe()["25%"])
#       3 mile_iqr_15 = 1.5*mile_iqr
#       4 mile_iqr_3  = 3*mile_iqr
#       5 # Inner and outer  Lower fences:
#
# NameError: name 'df_full' is not defined

# %%
otliers_index = df_full[(df_full["Mileage"] <= lower_outer) | (df_full["Mileage"] >= upper_outer)].index

# %%
df_full.drop(otliers_index, inplace = True)

# %%
df_full
# Out:
#          Price  Year  Mileage            City State                Vin   Make  \
# 0        16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1        15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2        16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3        15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4        16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
# ...        ...   ...      ...             ...   ...                ...    ...
# 2068367  63215  2017        9     Culver City    CA  YV1A22MK9H1013237  Volvo
# 2068368  72260  2017     3201       Englewood    NJ  YV4A22PL3H1186162  Volvo
# 2068369  55999  2016    28941    Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 2068370  60240  2017     3005     San Leandro    CA  YV4A22NLXH1006162  Volvo
# 2068371  76995  2017     2502        New York    NY  YV4BC0ZX1H1109845  Volvo
#
#                      Model
# 0        EncoreConvenience
# 1                EncoreFWD
# 2            EncoreLeather
# 3                EncoreFWD
# 4        EncoreConvenience
# ...                    ...
# 2068367              S90T6
# 2068368             XC90T6
# 2068369            XC90AWD
# 2068370                V90
# 2068371             XC90T8
#
# [2060491 rows x 8 columns]

# %%
#Agian Plotting mileage:
i = "Mileage"
print("Descriptive Statistics is for columns {} :\n {}".format(i, df_full[i].describe()))
fig, ax = plt.subplots(2,1, figsize = (10,10))
ax[0].set_title(f"Box Plot For Columns {i}")
ax[0].boxplot(df_full[i], vert = False, sym = "r.")
ax[1].set_title(f"Histogram of values for column {i}")
r = ax[1].hist(df_full[i], histtype = "bar")
ax[1].set_ylim(top = np.max(r[0]) + 10)
plt.show()
# Out:
# Descriptive Statistics is for columns Mileage :
#  count    2.060491e+06
# mean     5.189019e+04
# std      3.929531e+04
# min      5.000000e+00
# 25%      2.384400e+04
# 50%      4.028900e+04
# 75%      7.197400e+04
# max      2.182750e+05
# Name: Mileage, dtype: float64

# %% [markdown]
# Now the Mileage Shows a skewed behavior which may be reasonable due to the large density of older cars appears, so as we can assume older cars made more mileage.

# %% [markdown]
# <span id="cat"></span>
#
# #### 3.5.1.2 Categorical Columns:

# %%
# Calculating Value Counts:
for i in df_full.columns.to_list():
    if str(df_full[i].dtype) == 'object':
        print(f" ============ Categorical Columns {i} ===========")
        print(f" ============ Unique Values ===========")
        print(df_full[i].unique())
        print(f" ============ Value Counts ===========")
        print(df_full[i].value_counts())
# Out:
#  ============ Categorical Columns City ===========
#  ============ Unique Values ===========
# ['Jefferson City' 'Highland' 'Boone' ... 'Northfield' 'Huntington Valley'
#  'Winslow']
#  ============ Value Counts ===========
# Houston         32923
# San Antonio     19654
# Louisville      15212
# Jacksonville    13774
# Austin          13127
#                 ...
# Armona              8
# Port Jervis         8
# Los Banos           8
# Royston             4
# Eminence            1
# Name: City, Length: 2599, dtype: int64
#  ============ Categorical Columns State ===========
#  ============ Unique Values ===========
# [' MO' ' IN' ' NC' ' LA' ' NV' ' NY' ' CA' ' AR' ' FL' ' AZ' ' KY' ' TN'
#  ' MI' ' TX' ' PA' ' OK' ' NJ' ' MD' ' OH' ' GA' ' Va' ' Fl' ' CO' ' ND'
#  ' AL' ' IL' ' MA' ' WA' ' WI' ' MN' ' VA' ' KS' ' RI' ' OR' ' MS' ' NM'
#  ' SC' ' NE' ' IA' ' NH' ' UT' ' ME' ' CT' ' HI' ' ID' ' DE' ' MT' ' WV'
#  ' WY' ' SD' ' AK' ' VT' ' Ga' ' ga' ' Md' ' Ca' ' Oh' ' Az' ' DC']
#  ============ Value Counts ===========
#  TX    233109
#  CA    194663
#  FL    178364
#  GA     94162
#  IL     93174
#  NC     89701
#  VA     83473
#  PA     68232
#  NJ     65917
#  NY     65635
#  OH     56876
#  WA     55680
#  CO     55276
#  AZ     54944
#  TN     46416
#  MA     43994
#  MD     42677
#  IN     39523
#  MO     39231
#  KY     33299
#  AL     31573
#  WI     27342
#  MN     26629
#  CT     25679
#  UT     25346
#  MI     25282
#  OR     24832
#  OK     24185
#  SC     23737
#  LA     19898
#  KS     18762
#  NV     17157
#  AR     16304
#  MS     14665
#  NH     13869
#  NE     11944
#  NM     11660
#  IA     11500
#  ID      8344
#  HI      6693
#  DE      6106
#  MT      4529
#  ME      4513
#  RI      4427
#  AK      3892
#  WV      3480
#  ND      2899
#  SD      2851
#  VT      2631
#  Fl      1836
#  WY      1563
#  Va       625
#  Md       374
#  Ga       306
#  ga       284
#  Az       154
#  Oh       147
#  Ca        75
#  DC        52
# Name: State, dtype: int64
#  ============ Categorical Columns Vin ===========
#  ============ Unique Values ===========
# ['KL4CJBSBXFB267643' 'KL4CJASB5FB245057' 'KL4CJCSB0FB264921' ...
#  'WVWHV7AJ0DW009210' 'WVWHV7AJ5DW082797' 'WVWHV7AJ4DW123050']
#  ============ Value Counts ===========
# 3FA6P0H93GR316968    3
# 2G1FB1EV2A9127699    3
# 2G11Y5SL4E9113294    3
# 1G11Y5SL5EU125232    3
# 2G1FB1E32F9136442    3
#                     ..
# 5FNYF4H37FB016763    1
# 5FNRL5H6XEB115282    1
# 5FNYF4H50FB032126    1
# 5FNRL5H63FB123449    1
# WVWHV7AJ4DW123050    1
# Name: Vin, Length: 1223229, dtype: int64
#  ============ Categorical Columns Make ===========
#  ============ Unique Values ===========
# ['Buick' 'Acura' 'Alfa' 'Aston' 'Audi' 'Bentley' 'BMW' 'Cadillac'
#  'Chevrolet' 'Chrysler' 'Dodge' 'FIAT' 'Ford' 'GMC' 'Honda' 'Genesis'
#  'Geo' 'Freightliner' 'Ferrari' 'Fisker' 'AM' 'Jeep' 'Kia' 'Lamborghini'
#  'Land' 'Lexus' 'Lincoln' 'Lotus' 'Maserati' 'Maybach' 'Mazda' 'McLaren'
#  'Mercedes-Benz' 'Mercury' 'MINI' 'Mitsubishi' 'Nissan' 'Oldsmobile'
#  'Plymouth' 'Pontiac' 'Porsche' 'Ram' 'Rolls-Royce' 'Saab' 'Saturn'
#  'Scion' 'smart' 'Subaru' 'Suzuki' 'Tesla' 'Toyota' 'Volkswagen' 'Volvo'
#  'HUMMER' 'Hyundai' 'INFINITI' 'Isuzu' 'Jaguar']
#  ============ Value Counts ===========
# Ford             270796
# Chevrolet        251266
# Toyota           191617
# Nissan           164652
# Honda            126415
# Jeep             100562
# Hyundai           90412
# Dodge             84333
# GMC               71493
# Kia               71428
# BMW               64802
# Mercedes-Benz     64388
# Volkswagen        56442
# Lexus             50289
# Chrysler          40129
# Subaru            40119
# Cadillac          36911
# Ram               35012
# Mazda             33182
# Buick             30609
# INFINITI          29964
# Audi              25226
# Acura             22030
# Lincoln           17145
# Volvo             12421
# MINI              10596
# Mitsubishi         9970
# Land               9935
# Porsche            9887
# Scion              7416
# Jaguar             5313
# FIAT               4395
# Pontiac            4288
# Mercury            2653
# Maserati           2425
# Saturn             2383
# HUMMER             2265
# smart              1695
# Suzuki              814
# Ferrari             765
# Bentley             734
# Saab                627
# Tesla               583
# Genesis             350
# Aston               298
# Oldsmobile          278
# Lamborghini         262
# Rolls-Royce         200
# Isuzu               173
# Plymouth            121
# McLaren             111
# Lotus                91
# Alfa                 88
# Fisker               44
# AM                   38
# Freightliner         24
# Maybach              21
# Geo                   5
# Name: Make, dtype: int64
#  ============ Categorical Columns Model ===========
#  ============ Unique Values ===========
# ['EncoreConvenience' 'EncoreFWD' 'EncoreLeather' ... 'CCSPORT'
#  'Passat*Clean' 'GTI4-Door,']
#  ============ Value Counts ===========
# Silverado         60438
# Grand             42619
# Accord            29284
# Altima2.5         28111
# Sierra            27419
#                   ...
# ForesterSports        1
# Fusionse              1
# TundraDouble          1
# Outback3.0R           1
# CruzeSEDAN            1
# Name: Model, Length: 3154, dtype: int64

# %% [markdown]
# - <b> For the City Column: </b>
# There are arround `2600` Cities that appears in the data but there are many of them that has low occurance in the data.
# - <b> For the State Columns: </b>
# `59` State appeared in the dataand this is not reasonable as the USA has only 50 States, so form the values there, there some duplicate values which appears in mixure of upper and lower charachters that represents the State names' so we we have to handle this by changing all states names' to be in UPPER Values
# - <b>For Vin Column:</b>
# It seams that there are duplicate offering for the same car as there are duplicate Vins and this is not acceptable as the one car has only one unique Vehicle Identity Number, so we will remove these duplicates.
# - <b>For the Make Column: </b>
# It appears that the data is diversified and has many manufacturers, but we will check for duplicates by converting all to be Upper case.
# - <b>For the Model Column:</b>
# It appears that the data has many may car models but we can change all to Upper case tp check if there is any duplicates.

# %% [markdown]
# <span id="statn"></span>
#
# ##### 3.5.1.2.1 Handling the State Names:
# By Converting all to Upper Case:

# %%
def upper_states(state):
    return state.upper()
df_full["State"] = df_full["State"].apply(upper_states)

# %%
len(df_full["State"].unique())
# Out:
# 51

# %% [markdown]
# There 50 States inside the USA and there is oe federal distinct state which is District of Columbia or DC.

# %%
df_full["State"].value_counts().sort_values(axis = "index")
# Out:
#  DC        52
#  WY      1563
#  VT      2631
#  SD      2851
#  ND      2899
#  WV      3480
#  AK      3892
#  RI      4427
#  ME      4513
#  MT      4529
#  DE      6106
#  HI      6693
#  ID      8344
#  IA     11500
#  NM     11660
#  NE     11944
#  NH     13869
#  MS     14665
#  AR     16304
#  NV     17157
#  KS     18762
#  LA     19898
#  SC     23737
#  OK     24185
#  OR     24832
#  MI     25282
#  UT     25346
#  CT     25679
#  MN     26629
#  WI     27342
#  AL     31573
#  KY     33299
#  MO     39231
#  IN     39523
#  MD     43051
#  MA     43994
#  TN     46416
#  AZ     55098
#  CO     55276
#  WA     55680
#  OH     57023
#  NY     65635
#  NJ     65917
#  PA     68232
#  VA     84098
#  NC     89701
#  IL     93174
#  GA     94752
#  FL    180200
#  CA    194738
#  TX    233109
# Name: State, dtype: int64

# %% [markdown]
# <span id="vin1"></span>
#
# ##### 3.5.1.2.1 VIN Duplicate Removal:
# Removing the duplicate ones.

# %%
# VIN Column Have some duplicates which is note allowed as each motor has only one IN
repeated_vin = df_full["Vin"].value_counts()[df_full["Vin"].value_counts() > 1].index

# %%
#Due to large number:
random_repeated = np.random.choice(repeated_vin, size = 100)
for vin in random_repeated:
    print(f"======= Repeated VIN {vin}")
    print(df_full[df_full["Vin"] == vin])
# Out:
# ======= Repeated VIN 2C4RDGBG9DR763550
#          Price  Year  Mileage           City State                Vin   Make  \
# 79051     9995  2013    85929  Fuquay Varina    NC  2C4RDGBG9DR763550  Dodge
# 1431750   9995  2013    85929  Fuquay Varina    NC  2C4RDGBG9DR763550  Dodge
#
#          Model
# 79051    Grand
# 1431750  Grand
# ======= Repeated VIN JN8AS5MT3EW604991
#          Price  Year  Mileage         City State                Vin    Make  \
# 1016571  14991  2014    29684  Gainesville    FL  JN8AS5MT3EW604991  Nissan
# 1860524  13954  2014    29684  Punta Gorda    FL  JN8AS5MT3EW604991  Nissan
#
#          Model
# 1016571  Rogue
# 1860524  Rogue
# ======= Repeated VIN 1D7HE28K99S782019
#          Price  Year  Mileage    City State                Vin   Make  \
# 74298    12985  2009    79724  Pueblo    CO  1D7HE28K99S782019  Dodge
# 1440281  12985  2009    79724  Pueblo    CO  1D7HE28K99S782019  Dodge
#
#              Model
# 74298    Dakota2WD
# 1440281  Dakota2WD
# ======= Repeated VIN 1G1ZE5ST3GF237210
#          Price  Year  Mileage    City State                Vin       Make  \
# 136581   15988  2016    20654  Monroe    WA  1G1ZE5ST3GF237210  Chevrolet
# 1302153  15988  2016    20654  Monroe    WA  1G1ZE5ST3GF237210  Chevrolet
#
#             Model
# 136581   MalibuLT
# 1302153  MalibuLT
# ======= Repeated VIN 3C6TD5CT9CG195043
#          Price  Year  Mileage      City State                Vin Make    Model
# 1083630  26999  2012    63622  Puyallup    WA  3C6TD5CT9CG195043  Ram  25004WD
# 1933639  27999  2012    63622  Puyallup    WA  3C6TD5CT9CG195043  Ram  25004WD
# ======= Repeated VIN 4T4BF1FK8FR457082
#          Price  Year  Mileage       City State                Vin    Make  \
# 315031   15927  2015    27965  Turnwater    WA  4T4BF1FK8FR457082  Toyota
# 1966511  15927  2015    27965  Turnwater    WA  4T4BF1FK8FR457082  Toyota
#
#            Model
# 315031   CamryLE
# 1966511  CamryLE
# ======= Repeated VIN 2HKRM4H58EH693770
#          Price  Year  Mileage      City State                Vin   Make  \
# 769438   20990  2014    21451  Coos Bay    OR  2HKRM4H58EH693770  Honda
# 1623590  20990  2014    21451  Coos Bay    OR  2HKRM4H58EH693770  Honda
#
#           Model
# 769438   CR-VEX
# 1623590  CR-VEX
# ======= Repeated VIN 5N1AR2MM5EC629354
#          Price  Year  Mileage    City State                Vin    Make  \
# 291796   26499  2014    52726  Forest    VA  5N1AR2MM5EC629354  Nissan
# 1904664  26499  2014    52726  Forest    VA  5N1AR2MM5EC629354  Nissan
#
#                       Model
# 291796   PathfinderPlatinum
# 1904664  PathfinderPlatinum
# ======= Repeated VIN 2C4RC1BG0HR543218
#          Price  Year  Mileage   City State                Vin      Make  \
# 547744   26933  2017     9650  Tampa    FL  2C4RC1BG0HR543218  Chrysler
# 1411568  29442  2017     9650  Tampa    FL  2C4RC1BG0HR543218  Chrysler
#
#                    Model
# 547744   PacificaTouring
# 1411568  PacificaTouring
# ======= Repeated VIN 3GNEC16Z95G221289
#          Price  Year  Mileage  City State                Vin       Make  \
# 109029    7995  2005   117227  Mesa    AZ  3GNEC16Z95G221289  Chevrolet
# 1358108   7995  2005   117227  Mesa    AZ  3GNEC16Z95G221289  Chevrolet
#
#                Model
# 109029   Suburban4dr
# 1358108  Suburban4dr
# ======= Repeated VIN JTLZE4FE0FJ075081
#          Price  Year  Mileage         City State                Vin   Make  \
# 303409   12900  2015    29699  Lake Havasu    AZ  JTLZE4FE0FJ075081  Scion
# 1942773  12900  2015    29699  Lake Havasu    AZ  JTLZE4FE0FJ075081  Scion
#
#             Model
# 303409   xBManual
# 1942773  xBManual
# ======= Repeated VIN 2B3CJ4DG5BH565840
#          Price  Year  Mileage   City State                Vin   Make  \
# 568170   14900  2011    48674  Plano    TX  2B3CJ4DG5BH565840  Dodge
# 1431502  15900  2011    48674  Plano    TX  2B3CJ4DG5BH565840  Dodge
#
#                  Model
# 568170   Challenger2dr
# 1431502  Challenger2dr
# ======= Repeated VIN 1C4PJLAB2HW527317
#          Price  Year  Mileage        City State                Vin  Make  \
# 404741   21000  2017     7244  Louisville    KY  1C4PJLAB2HW527317  Jeep
# 1701032  21000  2017     7244  Louisville    KY  1C4PJLAB2HW527317  Jeep
#
#                  Model
# 404741   CherokeeSport
# 1701032  CherokeeSport
# ======= Repeated VIN JN8AS5MT8DW555091
#          Price  Year  Mileage     City State                Vin    Make  \
# 1030035  12980  2013    39251  Bradley    IL  JN8AS5MT8DW555091  Nissan
# 1875152  12980  2013    39251  Bradley    IL  JN8AS5MT8DW555091  Nissan
#
#           Model
# 1030035  RogueS
# 1875152  RogueS
# ======= Repeated VIN 5XXGU4L34GG021300
#          Price  Year  Mileage    City State                Vin Make     Model
# 895455   17995  2016    23858  Newnan    GA  5XXGU4L34GG021300  Kia  OptimaEX
# 1745591  18995  2016    23858  Newnan    GA  5XXGU4L34GG021300  Kia  OptimaEX
# ======= Repeated VIN 1G1ZE5ST6HF112915
#          Price  Year  Mileage   City State                Vin       Make  \
# 438806   16000  2017    38701  Sandy    UT  1G1ZE5ST6HF112915  Chevrolet
# 1305073  16733  2017    36628  Sandy    UT  1G1ZE5ST6HF112915  Chevrolet
#
#             Model
# 438806   MalibuLT
# 1305073  MalibuLT
# ======= Repeated VIN 1VWBN7A3XDC044858
#          Price  Year  Mileage    City State                Vin        Make  \
# 1199187  14337  2013    63899  Durham    NC  1VWBN7A3XDC044858  Volkswagen
# 2053413  15993  2013    63899  Durham    NC  1VWBN7A3XDC044858  Volkswagen
#
#              Model
# 1199187  PassatTDI
# 2053413  PassatTDI
# ======= Repeated VIN 5NPEB4AC9EH900714
#          Price  Year  Mileage     City State                Vin     Make  \
# 380915    9994  2014    38276  Seffner    FL  5NPEB4AC9EH900714  Hyundai
# 1648023   9994  2014    38276  Seffner    FL  5NPEB4AC9EH900714  Hyundai
#
#              Model
# 380915   SonataGLS
# 1648023  SonataGLS
# ======= Repeated VIN 5GAKRAKD2HJ159372
#          Price  Year  Mileage    City State                Vin   Make  \
# 420067   35991  2017    12980  Tucson    AZ  5GAKRAKD2HJ159372  Buick
# 1285015  35991  2017    12980  Tucson    AZ  5GAKRAKD2HJ159372  Buick
#
#                       Model
# 420067   EnclaveConvenience
# 1285015  EnclaveConvenience
# ======= Repeated VIN WBA1G9C58FVX96422
#          Price  Year  Mileage      City State                Vin Make Model
# 158458   28395  2015    16257  Harriman    NY  WBA1G9C58FVX96422  BMW     2
# 1260826  28395  2015    16257  Harriman    NY  WBA1G9C58FVX96422  BMW     2
# ======= Repeated VIN KMHGN4JE8FU040289
#          Price  Year  Mileage     City State                Vin     Make  \
# 826477   22980  2015    37676  Kendall    FL  KMHGN4JE8FU040289  Hyundai
# 1679004  24203  2015    37676  Kendall    FL  KMHGN4JE8FU040289  Hyundai
#
#                Model
# 826477   Genesis3.8L
# 1679004  Genesis3.8L
# ======= Repeated VIN 2C3KA43R67H600491
#          Price  Year  Mileage      City State                Vin      Make  \
# 89713     5950  2007    84548  Stafford    TX  2C3KA43R67H600491  Chrysler
# 1406838   5950  2007    84548  Stafford    TX  2C3KA43R67H600491  Chrysler
#
#           Model
# 89713    3004dr
# 1406838  3004dr
# ======= Repeated VIN 1GT22REG8GZ258074
#          Price  Year  Mileage     City State                Vin Make   Model
# 729630   36989  2016    11045  Nokomis    FL  1GT22REG8GZ258074  GMC  Sierra
# 1586797  38749  2016    11045  Nokomis    FL  1GT22REG8GZ258074  GMC  Sierra
# ======= Repeated VIN 1G1FB1RS3G0154851
#          Price  Year  Mileage         City State                Vin  \
# 119032   20992  2016    24387  San Antonio    TX  1G1FB1RS3G0154851
# 1337682  20992  2016    24387  San Antonio    TX  1G1FB1RS3G0154851
#
#               Make        Model
# 119032   Chevrolet  CamaroCoupe
# 1337682  Chevrolet  CamaroCoupe
# ======= Repeated VIN KM8J3CA24GU051366
#          Price  Year  Mileage      City State                Vin     Make  \
# 814101   17620  2016    34501  Stamford    CT  KM8J3CA24GU051366  Hyundai
# 1667986  18620  2016    34501  Stamford    CT  KM8J3CA24GU051366  Hyundai
#
#              Model
# 814101   TucsonAWD
# 1667986  TucsonAWD
# ======= Repeated VIN 2C3CCAGG6HH542499
#          Price  Year  Mileage          City State                Vin  \
# 553094   30995  2017     3258  Indian Trail    NC  2C3CCAGG6HH542499
# 1414417  30995  2017     3258  Indian Trail    NC  2C3CCAGG6HH542499
#
#              Make    Model
# 553094   Chrysler  300300S
# 1414417  Chrysler  300300S
# ======= Repeated VIN KNALW4D42F6021144
#          Price  Year  Mileage            City State                Vin Make  \
# 914117   29997  2015    18947  Ft. Lauderdale    FL  KNALW4D42F6021144  Kia
# 1762605  30997  2015    18947  Ft. Lauderdale    FL  KNALW4D42F6021144  Kia
#
#               Model
# 914117   K900Luxury
# 1762605  K900Luxury
# ======= Repeated VIN 2G4WS52J131266736
#          Price  Year  Mileage        City State                Vin   Make  \
# 145600    3588  2003   104320  Cookeville    TN  2G4WS52J131266736  Buick
# 1280441   3588  2003   104320  Cookeville    TN  2G4WS52J131266736  Buick
#
#               Model
# 145600   Century4dr
# 1280441  Century4dr
# ======= Repeated VIN 1C4NJRFB2FD257260
#          Price  Year  Mileage            City State                Vin  Make  \
# 407770   15999  2015    41189  Hendersonville    NC  1C4NJRFB2FD257260  Jeep
# 1707763  15999  2015    41189  Hendersonville    NC  1C4NJRFB2FD257260  Jeep
#
#                    Model
# 407770   PatriotLatitude
# 1707763  PatriotLatitude
# ======= Repeated VIN 3FA6P0HD4ER202348
#          Price  Year  Mileage    City State                Vin  Make     Model
# 608217   14495  2014    52223  Harlan    IA  3FA6P0HD4ER202348  Ford  FusionSE
# 1468563  14495  2014    52223  Harlan    IA  3FA6P0HD4ER202348  Ford  FusionSE
# ======= Repeated VIN 5NPE24AF1GH311766
#          Price  Year  Mileage         City State                Vin     Make  \
# 799918   15888  2016    28304  Clarksville    MD  5NPE24AF1GH311766  Hyundai
# 1655281  16888  2016    28304  Clarksville    MD  5NPE24AF1GH311766  Hyundai
#
#               Model
# 799918   Sonata2.4L
# 1655281  Sonata2.4L
# ======= Repeated VIN 2G1105S39H9119412
#          Price  Year  Mileage           City State                Vin  \
# 472315   19906  2017    18857  Oklahoma City    OK  2G1105S39H9119412
# 1334484  19211  2017    18857  Oklahoma City    OK  2G1105S39H9119412
#
#               Make     Model
# 472315   Chevrolet  ImpalaLT
# 1334484  Chevrolet  ImpalaLT
# ======= Repeated VIN 2T1KU4EE8CC764875
#          Price  Year  Mileage     City State                Vin    Make  \
# 322656    9999  2012    58910  Bastrop    TX  2T1KU4EE8CC764875  Toyota
# 1980943   9999  2012    58910  Bastrop    TX  2T1KU4EE8CC764875  Toyota
#
#              Model
# 322656   Matrix5dr
# 1980943  Matrix5dr
# ======= Repeated VIN 1C3CDFBB6FD199967
#          Price  Year  Mileage     City State                Vin   Make  \
# 82022    11995  2015    45006  El Paso    TX  1C3CDFBB6FD199967  Dodge
# 1425297  11995  2015    45006  El Paso    TX  1C3CDFBB6FD199967  Dodge
#
#            Model
# 82022    DartSXT
# 1425297  DartSXT
# ======= Repeated VIN 5N1AR2MM6GC632640
#          Price  Year  Mileage     City State                Vin    Make  \
# 1048241  21450  2016    40165  Ephrata    PA  5N1AR2MM6GC632640  Nissan
# 1911139  21450  2016    40165  Ephrata    PA  5N1AR2MM6GC632640  Nissan
#
#                 Model
# 1048241  PathfinderSV
# 1911139  PathfinderSV
# ======= Repeated VIN ZACCJBBT9GPD02033
#          Price  Year  Mileage  City State                Vin  Make  \
# 859532   18450  2016    42502  Reno    NV  ZACCJBBT9GPD02033  Jeep
# 1710563  18990  2016    42502  Reno    NV  ZACCJBBT9GPD02033  Jeep
#
#                     Model
# 859532   RenegadeLatitude
# 1710563  RenegadeLatitude
# ======= Repeated VIN 1FTFW1EF2CKD14348
#          Price  Year  Mileage    City State                Vin  Make     Model
# 40345    22988  2012    80850  Denver    CO  1FTFW1EF2CKD14348  Ford  F-1504WD
# 1517902  22988  2012    80850  Denver    CO  1FTFW1EF2CKD14348  Ford  F-1504WD
# ======= Repeated VIN 5TFRM5F18GX095420
#          Price  Year  Mileage   City State                Vin    Make   Model
# 335049   26977  2016    23570  Hemet    CA  5TFRM5F18GX095420  Toyota  Tundra
# 2006218  26977  2016    23570  Hemet    CA  5TFRM5F18GX095420  Toyota  Tundra
# ======= Repeated VIN 1FM5K8GT9EGC48157
#          Price  Year  Mileage         City State                Vin  Make  \
# 28019    36995  2014    28829  Idaho Falls    ID  1FM5K8GT9EGC48157  Ford
# 1547100  36995  2014    28829  Idaho Falls    ID  1FM5K8GT9EGC48157  Ford
#
#                  Model
# 28019    ExplorerSport
# 1547100  ExplorerSport
# ======= Repeated VIN 4T1BF1FK4FU484614
#          Price  Year  Mileage   City State                Vin    Make    Model
# 1128035  17477  2015    31602  Salem    OR  4T1BF1FK4FU484614  Toyota  CamrySE
# 1980789  17999  2015    31602  Salem    OR  4T1BF1FK4FU484614  Toyota  CamrySE
# ======= Repeated VIN 1N4AL3AP4EN372966
#          Price  Year  Mileage       City State                Vin    Make  \
# 271440   14149  2014    32238  Nashville    TN  1N4AL3AP4EN372966  Nissan
# 1859111  14149  2014    32238  Nashville    TN  1N4AL3AP4EN372966  Nissan
#
#              Model
# 271440   Altima2.5
# 1859111  Altima2.5
# ======= Repeated VIN 2C4RDGBG4DR599091
#          Price  Year  Mileage        City State                Vin   Make  \
# 571024   13488  2013    46648  Woodbridge    VA  2C4RDGBG4DR599091  Dodge
# 1432157  13488  2013    46648  Woodbridge    VA  2C4RDGBG4DR599091  Dodge
#
#          Model
# 571024   Grand
# 1432157  Grand
# ======= Repeated VIN 19UUB1F3XFA006945
#          Price  Year  Mileage   City State                Vin   Make   Model
# 203662   19884  2015    38039  Derby    CT  19UUB1F3XFA006945  Acura  TLXFWD
# 1219602  19884  2015    38039  Derby    CT  19UUB1F3XFA006945  Acura  TLXFWD
# ======= Repeated VIN 1GCRKSE7XCZ335897
#          Price  Year  Mileage       City State                Vin       Make  \
# 504617   22744  2012    94576  Boyertown    PA  1GCRKSE7XCZ335897  Chevrolet
# 1363744  21989  2012    94576  Boyertown    PA  1GCRKSE7XCZ335897  Chevrolet
#
#              Model
# 504617   Silverado
# 1363744  Silverado
# ======= Repeated VIN 5J6TF2H5XFL001701
#          Price  Year  Mileage         City State                Vin   Make  \
# 776816   20599  2015    31566  Woods Cross    UT  5J6TF2H5XFL001701  Honda
# 1630904  20599  2015    31566  Woods Cross    UT  5J6TF2H5XFL001701  Honda
#
#                  Model
# 776816   CrosstourEX-L
# 1630904  CrosstourEX-L
# ======= Repeated VIN 3GCUKSEJ7FG427365
#          Price  Year  Mileage         City State                Vin  \
# 521754   40195  2015    16143  Albuquerque    NM  3GCUKSEJ7FG427365
# 1386760  42534  2015    16143  Albuquerque    NM  3GCUKSEJ7FG427365
#
#               Make      Model
# 521754   Chevrolet  Silverado
# 1386760  Chevrolet  Silverado
# ======= Repeated VIN 1FTFW1ET3EFC88926
#          Price  Year  Mileage      City State                Vin  Make  \
# 691722   36865  2014    40672  Florence    SC  1FTFW1ET3EFC88926  Ford
# 1548809  36865  2014    40671  Florence    SC  1FTFW1ET3EFC88926  Ford
#
#             Model
# 691722   F-1504WD
# 1548809  F-1504WD
# ======= Repeated VIN 1C4BJWEG9CL118582
#          Price  Year  Mileage         City State                Vin  Make  \
# 880563   26795  2012    58225  Murrysville    PA  1C4BJWEG9CL118582  Jeep
# 1736065  26795  2012    58225  Murrysville    PA  1C4BJWEG9CL118582  Jeep
#
#             Model
# 880563   Wrangler
# 1736065  Wrangler
# ======= Repeated VIN 5N1AR2MM1FC643978
#          Price  Year  Mileage         City State                Vin    Make  \
# 286787   21995  2015    40587  Springfield    PA  5N1AR2MM1FC643978  Nissan
# 1892672  21995  2015    40587  Springfield    PA  5N1AR2MM1FC643978  Nissan
#
#                  Model
# 286787   Pathfinder4WD
# 1892672  Pathfinder4WD
# ======= Repeated VIN 1G1YL2D7XE5100574
#          Price  Year  Mileage        City State                Vin       Make  \
# 533592   41980  2014    40190  Georgetown    TX  1G1YL2D7XE5100574  Chevrolet
# 1397097  43705  2014    40190  Georgetown    TX  1G1YL2D7XE5100574  Chevrolet
#
#             Model
# 533592   Corvette
# 1397097  Corvette
# ======= Repeated VIN JF2SJAEC4HH532025
#          Price  Year  Mileage     City State                Vin    Make  \
# 308701   25995  2017      908  Emerson    NJ  JF2SJAEC4HH532025  Subaru
# 1953686  25995  2017      908  Emerson    NJ  JF2SJAEC4HH532025  Subaru
#
#                 Model
# 308701   Forester2.5i
# 1953686  Forester2.5i
# ======= Repeated VIN 5FNYF4H58FB022489
#          Price  Year  Mileage    City State                Vin   Make  \
# 785534   27722  2015    56169  Scotia    NY  5FNYF4H58FB022489  Honda
# 1645059  28422  2015    56169  Scotia    NY  5FNYF4H58FB022489  Honda
#
#              Model
# 785534   PilotEX-L
# 1645059  PilotEX-L
# ======= Repeated VIN 5N1AZ2MH3FN214526
#          Price  Year  Mileage        City State                Vin    Make  \
# 1061874  33995  2015    17436  Bloomfield    NJ  5N1AZ2MH3FN214526  Nissan
# 1905054  33995  2015    17436  Bloomfield    NJ  5N1AZ2MH3FN214526  Nissan
#
#              Model
# 1061874  MuranoAWD
# 1905054  MuranoAWD
# ======= Repeated VIN 55SWF4KB2GU125056
#          Price  Year  Mileage     City State                Vin  \
# 975280   35980  2016    11314  Bradley    IL  55SWF4KB2GU125056
# 1822674  35980  2016    11314  Bradley    IL  55SWF4KB2GU125056
#
#                   Make        Model
# 975280   Mercedes-Benz  C-ClassC300
# 1822674  Mercedes-Benz  C-ClassC300
# ======= Repeated VIN 1GKS1KE04ER191794
#          Price  Year  Mileage     City State                Vin Make  Model
# 723801   18580  2014   123046  Anaheim    CA  1GKS1KE04ER191794  GMC  Yukon
# 1580930  19394  2014   123046  Anaheim    CA  1GKS1KE04ER191794  GMC  Yukon
# ======= Repeated VIN 3FADP4BJ5DM130035
#          Price  Year  Mileage       City State                Vin  Make  \
# 614656    5300  2013   105091  St George    UT  3FADP4BJ5DM130035  Ford
# 1474797   5300  2013   105091  St George    UT  3FADP4BJ5DM130035  Ford
#
#                Model
# 614656   FiestaSedan
# 1474797  FiestaSedan
# ======= Repeated VIN 3GCUKREC8FG330069
#          Price  Year  Mileage           City State                Vin  \
# 102178   34999  2015    19925  Bowling Green    KY  3GCUKREC8FG330069
# 1375893  34999  2015    19925  Bowling Green    KY  3GCUKREC8FG330069
#
#               Make      Model
# 102178   Chevrolet  Silverado
# 1375893  Chevrolet  Silverado
# ======= Repeated VIN 4T4BF1FKXER391438
#          Price  Year  Mileage     City State                Vin    Make  \
# 315311   12997  2014    27231  Wichita    KS  4T4BF1FKXER391438  Toyota
# 1966992  12997  2014    27231  Wichita    KS  4T4BF1FKXER391438  Toyota
#
#            Model
# 315311   CamryLE
# 1966992  CamryLE
# ======= Repeated VIN WDDHF9AB3AA133763
#          Price  Year  Mileage              City State                Vin  \
# 975963   19995  2010    63887  South Hackensack    NJ  WDDHF9AB3AA133763
# 1823196  19900  2010    63877          Paterson    NJ  WDDHF9AB3AA133763
#
#                   Make       Model
# 975963   Mercedes-Benz  E-Class4dr
# 1823196  Mercedes-Benz  E-Class4dr
# ======= Repeated VIN 5NPEC4AC2DH540326
#          Price  Year  Mileage      City State                Vin     Make  \
# 824473   12995  2013    82019  Lawndale    CA  5NPEC4AC2DH540326  Hyundai
# 1676409  12995  2013    82019  Lawndale    CA  5NPEC4AC2DH540326  Hyundai
#
#                  Model
# 824473   SonataLimited
# 1676409  SonataLimited
# ======= Repeated VIN 5GAKRCED6CJ132286
#          Price  Year  Mileage       City State                Vin   Make  \
# 413708   13980  2012   102693  Lancaster    OH  5GAKRCED6CJ132286  Buick
# 1280325  14200  2012   102693  Lancaster    OH  5GAKRCED6CJ132286  Buick
#
#                   Model
# 413708   EnclaveLeather
# 1280325  EnclaveLeather
# ======= Repeated VIN 4T1BF1FK5FU064795
#          Price  Year  Mileage     City State                Vin    Make  \
# 1152134  13499  2015    39976  Jamaica    NY  4T1BF1FK5FU064795  Toyota
# 2003331  13499  2015    39976  Jamaica    NY  4T1BF1FK5FU064795  Toyota
#
#             Model
# 1152134  CamryXSE
# 2003331  CamryXSE
# ======= Repeated VIN JTNBB46K673007722
#          Price  Year  Mileage         City State                Vin    Make  \
# 1132398   4900  2007   182011  Wallingford    CT  JTNBB46K673007722  Toyota
# 1983560   4900  2007   182011  Wallingford    CT  JTNBB46K673007722  Toyota
#
#              Model
# 1132398  CamryBase
# 1983560      Camry
# ======= Repeated VIN 1FADP3N20FL328279
#          Price  Year  Mileage      City State                Vin  Make  \
# 59502    15977  2015    21804  Longview    TX  1FADP3N20FL328279  Ford
# 1476083  15977  2015    21804  Longview    TX  1FADP3N20FL328279  Ford
#
#                   Model
# 59502    FocusHatchback
# 1476083  FocusHatchback
# ======= Repeated VIN KNDJN2A26G7844305
#          Price  Year  Mileage        City State                Vin Make  \
# 223463   14974  2016     6360  Shrewsbury    MA  KNDJN2A26G7844305  Kia
# 1749091  14974  2016     6360  Shrewsbury    MA  KNDJN2A26G7844305  Kia
#
#               Model
# 223463   SoulManual
# 1749091  SoulManual
# ======= Repeated VIN 1NXBU4EE3AZ202930
#          Price  Year  Mileage        City State                Vin    Make  \
# 317386    8000  2010    91910  Brookfield    WI  1NXBU4EE3AZ202930  Toyota
# 1970771   8000  2010    91910  Brookfield    WI  1NXBU4EE3AZ202930  Toyota
#
#               Model
# 317386   Corolla4dr
# 1970771  Corolla4dr
# ======= Repeated VIN 1HGCT1B81DA008140
#          Price  Year  Mileage              City State                Vin  \
# 366111   15955  2013    39478  District Heights    MD  1HGCT1B81DA008140
# 1617333  15955  2013    39478  District Heights    MD  1HGCT1B81DA008140
#
#           Make   Model
# 366111   Honda  Accord
# 1617333  Honda  Accord
# ======= Repeated VIN 5J6RE48558L013024
#          Price  Year  Mileage    City State                Vin   Make    Model
# 775652    6978  2008   181927  DAYTON    OH  5J6RE48558L013024  Honda   CR-VEX
# 1629872   6978  2008   181927  DAYTON    OH  5J6RE48558L013024  Honda  CR-V4WD
# ======= Repeated VIN 3C4PDCBG8HT515647
#          Price  Year  Mileage       City State                Vin   Make  \
# 565883   17544  2017    30720  Ridgeland    MS  3C4PDCBG8HT515647  Dodge
# 1428157  17988  2017    30720  Ridgeland    MS  3C4PDCBG8HT515647  Dodge
#
#               Model
# 565883   JourneySXT
# 1428157  JourneySXT
# ======= Repeated VIN 1G1BE5SM9H7207098
#          Price  Year  Mileage    City State                Vin       Make  \
# 444532   15900  2017    16318  Tucson    AZ  1G1BE5SM9H7207098  Chevrolet
# 1308563  16025  2017    15357  Tucson    AZ  1G1BE5SM9H7207098  Chevrolet
#
#               Model
# 444532   CruzeSedan
# 1308563  CruzeSedan
# ======= Repeated VIN 3N1AB7AP8HY233003
#          Price  Year  Mileage           City State                Vin    Make  \
# 1002738  14750  2017      679  Warner Robins    GA  3N1AB7AP8HY233003  Nissan
# 1849732  14974  2017      679  Warner Robins    GA  3N1AB7AP8HY233003  Nissan
#
#            Model
# 1002738  SentraS
# 1849732  SentraS
# ======= Repeated VIN 1GCDT146768271001
#          Price  Year  Mileage      City State                Vin       Make  \
# 487186    4995  2006   158377  Loveland    OH  1GCDT146768271001  Chevrolet
# 1351156   5495  2006   158377  Loveland    OH  1GCDT146768271001  Chevrolet
#
#                Model
# 487186   Colorado4WD
# 1351156  Colorado4WD
# ======= Repeated VIN WDCYC7DF2GX246495
#           Price  Year  Mileage       City State                Vin  \
# 261635   121995  2016    27085  Littleton    CO  WDCYC7DF2GX246495
# 1838359  121995  2016    27085  Littleton    CO  WDCYC7DF2GX246495
#
#                   Make       Model
# 261635   Mercedes-Benz  G-ClassAMG
# 1838359  Mercedes-Benz  G-ClassAMG
# ======= Repeated VIN 1FTFW1EF8DFA11889
#          Price  Year  Mileage    City State                Vin  Make  \
# 38733    24571  2013    51894  Vienna    VA  1FTFW1EF8DFA11889  Ford
# 1520860  24571  2013    51894  Vienna    VA  1FTFW1EF8DFA11889  Ford
#
#                   Model
# 38733    F-150SuperCrew
# 1520860  F-150SuperCrew
# ======= Repeated VIN 1GCVKNEHXHZ106958
#          Price  Year  Mileage      City State                Vin       Make  \
# 492234   30999  2017     2138  Rockford    MI  1GCVKNEHXHZ106958  Chevrolet
# 1358061  31999  2017     2138  Rockford    MI  1GCVKNEHXHZ106958  Chevrolet
#
#              Model
# 492234   Silverado
# 1358061  Silverado
# ======= Repeated VIN KNAFU6A27A5241492
#          Price  Year  Mileage       City State                Vin Make  \
# 914949    9995  2010    81240  Las Vegas    NV  KNAFU6A27A5241492  Kia
# 1763071   9995  2010    81240  Las Vegas    NV  KNAFU6A27A5241492  Kia
#
#            Model
# 914949   ForteEX
# 1763071    Forte
# ======= Repeated VIN 5NPEB4AC7BH043224
#          Price  Year  Mileage          City State                Vin     Make  \
# 384613    7991  2011    82438  Garden Grove    CA  5NPEB4AC7BH043224  Hyundai
# 1655119   7991  2011    82438  Garden Grove    CA  5NPEB4AC7BH043224  Hyundai
#
#              Model
# 384613   Sonata4dr
# 1655119  Sonata4dr
# ======= Repeated VIN 5UXWX9C59E0D26826
#          Price  Year  Mileage     City State                Vin Make  \
# 168333   22995  2014    44937  Burbank    CA  5UXWX9C59E0D26826  BMW
# 1252481  22995  2014    44937  Burbank    CA  5UXWX9C59E0D26826  BMW
#
#                Model
# 168333   X3xDrive28i
# 1252481  X3xDrive28i
# ======= Repeated VIN 1C6RD6LT3CS324516
#          Price  Year  Mileage     City State                Vin Make    Model
# 298851   20995  2012    67535  Concord    CA  1C6RD6LT3CS324516  Ram  15002WD
# 1924061  20995  2012    67535  Concord    CA  1C6RD6LT3CS324516  Ram  15002WD
# ======= Repeated VIN 3FAHP0GAXCR419917
#          Price  Year  Mileage        City State                Vin  Make  \
# 616202   10795  2012    97798  Miamisburg    OH  3FAHP0GAXCR419917  Ford
# 1476297  10795  2012    97798  Miamisburg    OH  3FAHP0GAXCR419917  Ford
#
#              Model
# 616202     FusionS
# 1476297  Fusion4dr
# ======= Repeated VIN 3GCUKREC0EG311904
#          Price  Year  Mileage   City State                Vin       Make  \
# 521515   39522  2014    13768  Nampa    ID  3GCUKREC0EG311904  Chevrolet
# 1377989  36990  2014    13768  Boise    ID  3GCUKREC0EG311904  Chevrolet
#
#              Model
# 521515   Silverado
# 1377989  Silverado
# ======= Repeated VIN 1D8GU58K87W611389
#          Price  Year  Mileage      City State                Vin   Make  \
# 74743    11595  2007    80648  Highland    IN  1D8GU58K87W611389  Dodge
# 1438974  11595  2007    80648  Highland    IN  1D8GU58K87W611389  Dodge
#
#             Model
# 74743    Nitro4WD
# 1438974  Nitro4WD
# ======= Repeated VIN 2T1BURHE3GC691820
#          Price  Year  Mileage         City State                Vin    Make  \
# 1135905  15991  2016    13422       Dothan    AL  2T1BURHE3GC691820  Toyota
# 1964369  15492  2016    13422  Panama City    FL  2T1BURHE3GC691820  Toyota
#
#              Model
# 1135905  CorollaLE
# 1964369  CorollaLE
# ======= Repeated VIN 1GCVKSEC1EZ394917
#          Price  Year  Mileage      City State                Vin       Make  \
# 512401   30790  2014    46317  Kennesaw    GA  1GCVKSEC1EZ394917  Chevrolet
# 1375624  31400  2014    46317  Kennesaw    GA  1GCVKSEC1EZ394917  Chevrolet
#
#              Model
# 512401   Silverado
# 1375624  Silverado
# ======= Repeated VIN 1C4NJRFB1ED904908
#          Price  Year  Mileage      City State                Vin  Make  \
# 851872   13882  2014    35663  Waukesha    WI  1C4NJRFB1ED904908  Jeep
# 1705965  15986  2014    35663  Waukesha    WI  1C4NJRFB1ED904908  Jeep
#
#                    Model
# 851872   PatriotLatitude
# 1705965  PatriotLatitude
# ======= Repeated VIN 3N1CE2CP3GL371219
#          Price  Year  Mileage       City State                Vin    Make  \
# 291754   16991  2016     6545  Oak Ridge    TN  3N1CE2CP3GL371219  Nissan
# 1904569  16991  2016     6545  Oak Ridge    TN  3N1CE2CP3GL371219  Nissan
#
#          Model
# 291754   Versa
# 1904569  Versa
# ======= Repeated VIN 1N4AA5AP6CC850671
#          Price  Year  Mileage         City State                Vin    Make  \
# 1018806  13988  2012    64137  San Antonio    TX  1N4AA5AP6CC850671  Nissan
# 1864529  13988  2012    64137  San Antonio    TX  1N4AA5AP6CC850671  Nissan
#
#              Model
# 1018806  Maxima4dr
# 1864529  Maxima4dr
# ======= Repeated VIN 2C4RDGCG3HR691409
#          Price  Year  Mileage          City State                Vin   Make  \
# 69551    23500  2017    24269  Grand Rapids    MI  2C4RDGCG3HR691409  Dodge
# 1450657  23500  2017    24269  Grand Rapids    MI  2C4RDGCG3HR691409  Dodge
#
#          Model
# 69551    Grand
# 1450657  Grand
# ======= Repeated VIN 1FMCU9GX4GUB62298
#          Price  Year  Mileage     City State                Vin  Make  \
# 620721   20500  2016    14590  Bel Air    MD  1FMCU9GX4GUB62298  Ford
# 1480986  20500  2016    14590  Bel Air    MD  1FMCU9GX4GUB62298  Ford
#
#              Model
# 620721    EscapeSE
# 1480986  Escape4WD
# ======= Repeated VIN 1C4BJWDG1EL309238
#          Price  Year  Mileage        City State                Vin  Make  \
# 875645   25990  2014    26890  Shrewsbury    NJ  1C4BJWDG1EL309238  Jeep
# 1726791  27990  2014    26890  Shrewsbury    NJ  1C4BJWDG1EL309238  Jeep
#
#             Model
# 875645   Wrangler
# 1726791  Wrangler
# ======= Repeated VIN WDBTJ56J66F170598
#          Price  Year  Mileage    City State                Vin           Make  \
# 253241    5730  2006   167598  Buford    GA  WDBTJ56J66F170598  Mercedes-Benz
# 1816976   5730  2006   167598  Buford    GA  WDBTJ56J66F170598  Mercedes-Benz
#
#                    Model
# 253241   CLK-ClassCLK350
# 1816976  CLK-ClassCLK350
# ======= Repeated VIN 4T4BF3EKXAR011053
#          Price  Year  Mileage        City State                Vin    Make  \
# 1128077  10409  2010    85645  Naperville    IL  4T4BF3EKXAR011053  Toyota
# 2007479   9800  2010    85644  Naperville    IL  4T4BF3EKXAR011053  Toyota
#
#              Model
# 1128077  CamryBase
# 2007479   Camry4dr
# ======= Repeated VIN 3C4PDCAB5ET270520
#          Price  Year  Mileage      City State                Vin   Make  \
# 79173    12999  2014    65488  Puyallup    WA  3C4PDCAB5ET270520  Dodge
# 1429705  12999  2014    65488  Puyallup    WA  3C4PDCAB5ET270520  Dodge
#
#              Model
# 79173    JourneySE
# 1429705  JourneySE
# ======= Repeated VIN 1FADP3L92EL200110
#          Price  Year  Mileage     City State                Vin  Make  \
# 628657   17994  2014    37649  Seattle    WA  1FADP3L92EL200110  Ford
# 1539317  17994  2014    37649  Seattle    WA  1FADP3L92EL200110  Ford
#
#                   Model
# 628657          FocusST
# 1539317  FocusHatchback
# ======= Repeated VIN 3GTU2NECXGG109213
#          Price  Year  Mileage    City State                Vin Make   Model
# 11183    37800  2016    34007  Linden    NJ  3GTU2NECXGG109213  GMC  Sierra
# 1585427  37800  2016    34007  Linden    NJ  3GTU2NECXGG109213  GMC  Sierra
# ======= Repeated VIN 3GTU2WEC5FG411335
#          Price  Year  Mileage   City State                Vin Make   Model
# 730307   36888  2015    55426  Baird    TX  3GTU2WEC5FG411335  GMC  Sierra
# 1587437  38999  2015    55426  Baird    TX  3GTU2WEC5FG411335  GMC  Sierra
# ======= Repeated VIN 2G1WF5E36D1265968
#          Price  Year  Mileage     City State                Vin       Make  \
# 120068   13795  2013    34857  Augusta    GA  2G1WF5E36D1265968  Chevrolet
# 1333529  13795  2013    34857  Augusta    GA  2G1WF5E36D1265968  Chevrolet
#
#             Model
# 120068   ImpalaLS
# 1333529  ImpalaLS
# ======= Repeated VIN 1GCNCPEX5BZ199623
#          Price  Year  Mileage             City State                Vin  \
# 125660   10995  2011    32322  North Attleboro    MA  1GCNCPEX5BZ199623
# 1324741  10995  2011    32322  North Attleboro    MA  1GCNCPEX5BZ199623
#
#               Make      Model
# 125660   Chevrolet  Silverado
# 1324741  Chevrolet  Silverado
# ======= Repeated VIN 2T1BU4EE7BC565962
#          Price  Year  Mileage    City State                Vin    Make  \
# 322766    9595  2011    93354  Fresno    CA  2T1BU4EE7BC565962  Toyota
# 1981170   9595  2011    93354  Fresno    CA  2T1BU4EE7BC565962  Toyota
#
#               Model
# 322766   Corolla4dr
# 1981170  Corolla4dr
# ======= Repeated VIN 1FA6P8TH3H5281897
#          Price  Year  Mileage     City State                Vin  Make  \
# 48746    24596  2017    16033  Atlanta    GA  1FA6P8TH3H5281897  Ford
# 1496236  24596  2017    16033  Atlanta    GA  1FA6P8TH3H5281897  Ford
#
#                    Model
# 48746    MustangEcoBoost
# 1496236  MustangEcoBoost

# %% [markdown]
# As we assume, most of entries that have the same Vin are duplicated, so we eill remove them and this will reduce the number of rows in the dataset signficantly.

# %%
#Removing Duplicate VINs
df_full.drop_duplicates(subset = "Vin", inplace= True)

# %%
#Checking subset of dropped duplicates
for vin in random_repeated:
    print(f"======= Repeated VIN {vin}")
    print(df_full[df_full["Vin"] == vin])
# Out:
# ======= Repeated VIN 2C4RDGBG9DR763550
#        Price  Year  Mileage           City State                Vin   Make  \
# 79051   9995  2013    85929  Fuquay Varina    NC  2C4RDGBG9DR763550  Dodge
#
#        Model
# 79051  Grand
# ======= Repeated VIN JN8AS5MT3EW604991
#          Price  Year  Mileage         City State                Vin    Make  \
# 1016571  14991  2014    29684  Gainesville    FL  JN8AS5MT3EW604991  Nissan
#
#          Model
# 1016571  Rogue
# ======= Repeated VIN 1D7HE28K99S782019
#        Price  Year  Mileage    City State                Vin   Make      Model
# 74298  12985  2009    79724  Pueblo    CO  1D7HE28K99S782019  Dodge  Dakota2WD
# ======= Repeated VIN 1G1ZE5ST3GF237210
#         Price  Year  Mileage    City State                Vin       Make  \
# 136581  15988  2016    20654  Monroe    WA  1G1ZE5ST3GF237210  Chevrolet
#
#            Model
# 136581  MalibuLT
# ======= Repeated VIN 3C6TD5CT9CG195043
#          Price  Year  Mileage      City State                Vin Make    Model
# 1083630  26999  2012    63622  Puyallup    WA  3C6TD5CT9CG195043  Ram  25004WD
# ======= Repeated VIN 4T4BF1FK8FR457082
#         Price  Year  Mileage       City State                Vin    Make  \
# 315031  15927  2015    27965  Turnwater    WA  4T4BF1FK8FR457082  Toyota
#
#           Model
# 315031  CamryLE
# ======= Repeated VIN 2HKRM4H58EH693770
#         Price  Year  Mileage      City State                Vin   Make   Model
# 769438  20990  2014    21451  Coos Bay    OR  2HKRM4H58EH693770  Honda  CR-VEX
# ======= Repeated VIN 5N1AR2MM5EC629354
#         Price  Year  Mileage    City State                Vin    Make  \
# 291796  26499  2014    52726  Forest    VA  5N1AR2MM5EC629354  Nissan
#
#                      Model
# 291796  PathfinderPlatinum
# ======= Repeated VIN 2C4RC1BG0HR543218
#         Price  Year  Mileage   City State                Vin      Make  \
# 547744  26933  2017     9650  Tampa    FL  2C4RC1BG0HR543218  Chrysler
#
#                   Model
# 547744  PacificaTouring
# ======= Repeated VIN 3GNEC16Z95G221289
#         Price  Year  Mileage  City State                Vin       Make  \
# 109029   7995  2005   117227  Mesa    AZ  3GNEC16Z95G221289  Chevrolet
#
#               Model
# 109029  Suburban4dr
# ======= Repeated VIN JTLZE4FE0FJ075081
#         Price  Year  Mileage         City State                Vin   Make  \
# 303409  12900  2015    29699  Lake Havasu    AZ  JTLZE4FE0FJ075081  Scion
#
#            Model
# 303409  xBManual
# ======= Repeated VIN 2B3CJ4DG5BH565840
#         Price  Year  Mileage   City State                Vin   Make  \
# 568170  14900  2011    48674  Plano    TX  2B3CJ4DG5BH565840  Dodge
#
#                 Model
# 568170  Challenger2dr
# ======= Repeated VIN 1C4PJLAB2HW527317
#         Price  Year  Mileage        City State                Vin  Make  \
# 404741  21000  2017     7244  Louisville    KY  1C4PJLAB2HW527317  Jeep
#
#                 Model
# 404741  CherokeeSport
# ======= Repeated VIN JN8AS5MT8DW555091
#          Price  Year  Mileage     City State                Vin    Make  \
# 1030035  12980  2013    39251  Bradley    IL  JN8AS5MT8DW555091  Nissan
#
#           Model
# 1030035  RogueS
# ======= Repeated VIN 5XXGU4L34GG021300
#         Price  Year  Mileage    City State                Vin Make     Model
# 895455  17995  2016    23858  Newnan    GA  5XXGU4L34GG021300  Kia  OptimaEX
# ======= Repeated VIN 1G1ZE5ST6HF112915
#         Price  Year  Mileage   City State                Vin       Make  \
# 438806  16000  2017    38701  Sandy    UT  1G1ZE5ST6HF112915  Chevrolet
#
#            Model
# 438806  MalibuLT
# ======= Repeated VIN 1VWBN7A3XDC044858
#          Price  Year  Mileage    City State                Vin        Make  \
# 1199187  14337  2013    63899  Durham    NC  1VWBN7A3XDC044858  Volkswagen
#
#              Model
# 1199187  PassatTDI
# ======= Repeated VIN 5NPEB4AC9EH900714
#         Price  Year  Mileage     City State                Vin     Make  \
# 380915   9994  2014    38276  Seffner    FL  5NPEB4AC9EH900714  Hyundai
#
#             Model
# 380915  SonataGLS
# ======= Repeated VIN 5GAKRAKD2HJ159372
#         Price  Year  Mileage    City State                Vin   Make  \
# 420067  35991  2017    12980  Tucson    AZ  5GAKRAKD2HJ159372  Buick
#
#                      Model
# 420067  EnclaveConvenience
# ======= Repeated VIN WBA1G9C58FVX96422
#         Price  Year  Mileage      City State                Vin Make Model
# 158458  28395  2015    16257  Harriman    NY  WBA1G9C58FVX96422  BMW     2
# ======= Repeated VIN KMHGN4JE8FU040289
#         Price  Year  Mileage     City State                Vin     Make  \
# 826477  22980  2015    37676  Kendall    FL  KMHGN4JE8FU040289  Hyundai
#
#               Model
# 826477  Genesis3.8L
# ======= Repeated VIN 2C3KA43R67H600491
#        Price  Year  Mileage      City State                Vin      Make  \
# 89713   5950  2007    84548  Stafford    TX  2C3KA43R67H600491  Chrysler
#
#         Model
# 89713  3004dr
# ======= Repeated VIN 1GT22REG8GZ258074
#         Price  Year  Mileage     City State                Vin Make   Model
# 729630  36989  2016    11045  Nokomis    FL  1GT22REG8GZ258074  GMC  Sierra
# ======= Repeated VIN 1G1FB1RS3G0154851
#         Price  Year  Mileage         City State                Vin       Make  \
# 119032  20992  2016    24387  San Antonio    TX  1G1FB1RS3G0154851  Chevrolet
#
#               Model
# 119032  CamaroCoupe
# ======= Repeated VIN KM8J3CA24GU051366
#         Price  Year  Mileage      City State                Vin     Make  \
# 814101  17620  2016    34501  Stamford    CT  KM8J3CA24GU051366  Hyundai
#
#             Model
# 814101  TucsonAWD
# ======= Repeated VIN 2C3CCAGG6HH542499
#         Price  Year  Mileage          City State                Vin      Make  \
# 553094  30995  2017     3258  Indian Trail    NC  2C3CCAGG6HH542499  Chrysler
#
#           Model
# 553094  300300S
# ======= Repeated VIN KNALW4D42F6021144
#         Price  Year  Mileage            City State                Vin Make  \
# 914117  29997  2015    18947  Ft. Lauderdale    FL  KNALW4D42F6021144  Kia
#
#              Model
# 914117  K900Luxury
# ======= Repeated VIN 2G4WS52J131266736
#         Price  Year  Mileage        City State                Vin   Make  \
# 145600   3588  2003   104320  Cookeville    TN  2G4WS52J131266736  Buick
#
#              Model
# 145600  Century4dr
# ======= Repeated VIN 1C4NJRFB2FD257260
#         Price  Year  Mileage            City State                Vin  Make  \
# 407770  15999  2015    41189  Hendersonville    NC  1C4NJRFB2FD257260  Jeep
#
#                   Model
# 407770  PatriotLatitude
# ======= Repeated VIN 3FA6P0HD4ER202348
#         Price  Year  Mileage    City State                Vin  Make     Model
# 608217  14495  2014    52223  Harlan    IA  3FA6P0HD4ER202348  Ford  FusionSE
# ======= Repeated VIN 5NPE24AF1GH311766
#         Price  Year  Mileage         City State                Vin     Make  \
# 799918  15888  2016    28304  Clarksville    MD  5NPE24AF1GH311766  Hyundai
#
#              Model
# 799918  Sonata2.4L
# ======= Repeated VIN 2G1105S39H9119412
#         Price  Year  Mileage           City State                Vin  \
# 472315  19906  2017    18857  Oklahoma City    OK  2G1105S39H9119412
#
#              Make     Model
# 472315  Chevrolet  ImpalaLT
# ======= Repeated VIN 2T1KU4EE8CC764875
#         Price  Year  Mileage     City State                Vin    Make  \
# 322656   9999  2012    58910  Bastrop    TX  2T1KU4EE8CC764875  Toyota
#
#             Model
# 322656  Matrix5dr
# ======= Repeated VIN 1C3CDFBB6FD199967
#        Price  Year  Mileage     City State                Vin   Make    Model
# 82022  11995  2015    45006  El Paso    TX  1C3CDFBB6FD199967  Dodge  DartSXT
# ======= Repeated VIN 5N1AR2MM6GC632640
#          Price  Year  Mileage     City State                Vin    Make  \
# 1048241  21450  2016    40165  Ephrata    PA  5N1AR2MM6GC632640  Nissan
#
#                 Model
# 1048241  PathfinderSV
# ======= Repeated VIN ZACCJBBT9GPD02033
#         Price  Year  Mileage  City State                Vin  Make  \
# 859532  18450  2016    42502  Reno    NV  ZACCJBBT9GPD02033  Jeep
#
#                    Model
# 859532  RenegadeLatitude
# ======= Repeated VIN 1FTFW1EF2CKD14348
#        Price  Year  Mileage    City State                Vin  Make     Model
# 40345  22988  2012    80850  Denver    CO  1FTFW1EF2CKD14348  Ford  F-1504WD
# ======= Repeated VIN 5TFRM5F18GX095420
#         Price  Year  Mileage   City State                Vin    Make   Model
# 335049  26977  2016    23570  Hemet    CA  5TFRM5F18GX095420  Toyota  Tundra
# ======= Repeated VIN 1FM5K8GT9EGC48157
#        Price  Year  Mileage         City State                Vin  Make  \
# 28019  36995  2014    28829  Idaho Falls    ID  1FM5K8GT9EGC48157  Ford
#
#                Model
# 28019  ExplorerSport
# ======= Repeated VIN 4T1BF1FK4FU484614
#          Price  Year  Mileage   City State                Vin    Make    Model
# 1128035  17477  2015    31602  Salem    OR  4T1BF1FK4FU484614  Toyota  CamrySE
# ======= Repeated VIN 1N4AL3AP4EN372966
#         Price  Year  Mileage       City State                Vin    Make  \
# 271440  14149  2014    32238  Nashville    TN  1N4AL3AP4EN372966  Nissan
#
#             Model
# 271440  Altima2.5
# ======= Repeated VIN 2C4RDGBG4DR599091
#         Price  Year  Mileage        City State                Vin   Make  \
# 571024  13488  2013    46648  Woodbridge    VA  2C4RDGBG4DR599091  Dodge
#
#         Model
# 571024  Grand
# ======= Repeated VIN 19UUB1F3XFA006945
#         Price  Year  Mileage   City State                Vin   Make   Model
# 203662  19884  2015    38039  Derby    CT  19UUB1F3XFA006945  Acura  TLXFWD
# ======= Repeated VIN 1GCRKSE7XCZ335897
#         Price  Year  Mileage       City State                Vin       Make  \
# 504617  22744  2012    94576  Boyertown    PA  1GCRKSE7XCZ335897  Chevrolet
#
#             Model
# 504617  Silverado
# ======= Repeated VIN 5J6TF2H5XFL001701
#         Price  Year  Mileage         City State                Vin   Make  \
# 776816  20599  2015    31566  Woods Cross    UT  5J6TF2H5XFL001701  Honda
#
#                 Model
# 776816  CrosstourEX-L
# ======= Repeated VIN 3GCUKSEJ7FG427365
#         Price  Year  Mileage         City State                Vin       Make  \
# 521754  40195  2015    16143  Albuquerque    NM  3GCUKSEJ7FG427365  Chevrolet
#
#             Model
# 521754  Silverado
# ======= Repeated VIN 1FTFW1ET3EFC88926
#         Price  Year  Mileage      City State                Vin  Make  \
# 691722  36865  2014    40672  Florence    SC  1FTFW1ET3EFC88926  Ford
#
#            Model
# 691722  F-1504WD
# ======= Repeated VIN 1C4BJWEG9CL118582
#         Price  Year  Mileage         City State                Vin  Make  \
# 880563  26795  2012    58225  Murrysville    PA  1C4BJWEG9CL118582  Jeep
#
#            Model
# 880563  Wrangler
# ======= Repeated VIN 5N1AR2MM1FC643978
#         Price  Year  Mileage         City State                Vin    Make  \
# 286787  21995  2015    40587  Springfield    PA  5N1AR2MM1FC643978  Nissan
#
#                 Model
# 286787  Pathfinder4WD
# ======= Repeated VIN 1G1YL2D7XE5100574
#         Price  Year  Mileage        City State                Vin       Make  \
# 533592  41980  2014    40190  Georgetown    TX  1G1YL2D7XE5100574  Chevrolet
#
#            Model
# 533592  Corvette
# ======= Repeated VIN JF2SJAEC4HH532025
#         Price  Year  Mileage     City State                Vin    Make  \
# 308701  25995  2017      908  Emerson    NJ  JF2SJAEC4HH532025  Subaru
#
#                Model
# 308701  Forester2.5i
# ======= Repeated VIN 5FNYF4H58FB022489
#         Price  Year  Mileage    City State                Vin   Make  \
# 785534  27722  2015    56169  Scotia    NY  5FNYF4H58FB022489  Honda
#
#             Model
# 785534  PilotEX-L
# ======= Repeated VIN 5N1AZ2MH3FN214526
#          Price  Year  Mileage        City State                Vin    Make  \
# 1061874  33995  2015    17436  Bloomfield    NJ  5N1AZ2MH3FN214526  Nissan
#
#              Model
# 1061874  MuranoAWD
# ======= Repeated VIN 55SWF4KB2GU125056
#         Price  Year  Mileage     City State                Vin           Make  \
# 975280  35980  2016    11314  Bradley    IL  55SWF4KB2GU125056  Mercedes-Benz
#
#               Model
# 975280  C-ClassC300
# ======= Repeated VIN 1GKS1KE04ER191794
#         Price  Year  Mileage     City State                Vin Make  Model
# 723801  18580  2014   123046  Anaheim    CA  1GKS1KE04ER191794  GMC  Yukon
# ======= Repeated VIN 3FADP4BJ5DM130035
#         Price  Year  Mileage       City State                Vin  Make  \
# 614656   5300  2013   105091  St George    UT  3FADP4BJ5DM130035  Ford
#
#               Model
# 614656  FiestaSedan
# ======= Repeated VIN 3GCUKREC8FG330069
#         Price  Year  Mileage           City State                Vin  \
# 102178  34999  2015    19925  Bowling Green    KY  3GCUKREC8FG330069
#
#              Make      Model
# 102178  Chevrolet  Silverado
# ======= Repeated VIN 4T4BF1FKXER391438
#         Price  Year  Mileage     City State                Vin    Make  \
# 315311  12997  2014    27231  Wichita    KS  4T4BF1FKXER391438  Toyota
#
#           Model
# 315311  CamryLE
# ======= Repeated VIN WDDHF9AB3AA133763
#         Price  Year  Mileage              City State                Vin  \
# 975963  19995  2010    63887  South Hackensack    NJ  WDDHF9AB3AA133763
#
#                  Make       Model
# 975963  Mercedes-Benz  E-Class4dr
# ======= Repeated VIN 5NPEC4AC2DH540326
#         Price  Year  Mileage      City State                Vin     Make  \
# 824473  12995  2013    82019  Lawndale    CA  5NPEC4AC2DH540326  Hyundai
#
#                 Model
# 824473  SonataLimited
# ======= Repeated VIN 5GAKRCED6CJ132286
#         Price  Year  Mileage       City State                Vin   Make  \
# 413708  13980  2012   102693  Lancaster    OH  5GAKRCED6CJ132286  Buick
#
#                  Model
# 413708  EnclaveLeather
# ======= Repeated VIN 4T1BF1FK5FU064795
#          Price  Year  Mileage     City State                Vin    Make  \
# 1152134  13499  2015    39976  Jamaica    NY  4T1BF1FK5FU064795  Toyota
#
#             Model
# 1152134  CamryXSE
# ======= Repeated VIN JTNBB46K673007722
#          Price  Year  Mileage         City State                Vin    Make  \
# 1132398   4900  2007   182011  Wallingford    CT  JTNBB46K673007722  Toyota
#
#              Model
# 1132398  CamryBase
# ======= Repeated VIN 1FADP3N20FL328279
#        Price  Year  Mileage      City State                Vin  Make  \
# 59502  15977  2015    21804  Longview    TX  1FADP3N20FL328279  Ford
#
#                 Model
# 59502  FocusHatchback
# ======= Repeated VIN KNDJN2A26G7844305
#         Price  Year  Mileage        City State                Vin Make  \
# 223463  14974  2016     6360  Shrewsbury    MA  KNDJN2A26G7844305  Kia
#
#              Model
# 223463  SoulManual
# ======= Repeated VIN 1NXBU4EE3AZ202930
#         Price  Year  Mileage        City State                Vin    Make  \
# 317386   8000  2010    91910  Brookfield    WI  1NXBU4EE3AZ202930  Toyota
#
#              Model
# 317386  Corolla4dr
# ======= Repeated VIN 1HGCT1B81DA008140
#         Price  Year  Mileage              City State                Vin  \
# 366111  15955  2013    39478  District Heights    MD  1HGCT1B81DA008140
#
#          Make   Model
# 366111  Honda  Accord
# ======= Repeated VIN 5J6RE48558L013024
#         Price  Year  Mileage    City State                Vin   Make   Model
# 775652   6978  2008   181927  DAYTON    OH  5J6RE48558L013024  Honda  CR-VEX
# ======= Repeated VIN 3C4PDCBG8HT515647
#         Price  Year  Mileage       City State                Vin   Make  \
# 565883  17544  2017    30720  Ridgeland    MS  3C4PDCBG8HT515647  Dodge
#
#              Model
# 565883  JourneySXT
# ======= Repeated VIN 1G1BE5SM9H7207098
#         Price  Year  Mileage    City State                Vin       Make  \
# 444532  15900  2017    16318  Tucson    AZ  1G1BE5SM9H7207098  Chevrolet
#
#              Model
# 444532  CruzeSedan
# ======= Repeated VIN 3N1AB7AP8HY233003
#          Price  Year  Mileage           City State                Vin    Make  \
# 1002738  14750  2017      679  Warner Robins    GA  3N1AB7AP8HY233003  Nissan
#
#            Model
# 1002738  SentraS
# ======= Repeated VIN 1GCDT146768271001
#         Price  Year  Mileage      City State                Vin       Make  \
# 487186   4995  2006   158377  Loveland    OH  1GCDT146768271001  Chevrolet
#
#               Model
# 487186  Colorado4WD
# ======= Repeated VIN WDCYC7DF2GX246495
#          Price  Year  Mileage       City State                Vin  \
# 261635  121995  2016    27085  Littleton    CO  WDCYC7DF2GX246495
#
#                  Make       Model
# 261635  Mercedes-Benz  G-ClassAMG
# ======= Repeated VIN 1FTFW1EF8DFA11889
#        Price  Year  Mileage    City State                Vin  Make  \
# 38733  24571  2013    51894  Vienna    VA  1FTFW1EF8DFA11889  Ford
#
#                 Model
# 38733  F-150SuperCrew
# ======= Repeated VIN 1GCVKNEHXHZ106958
#         Price  Year  Mileage      City State                Vin       Make  \
# 492234  30999  2017     2138  Rockford    MI  1GCVKNEHXHZ106958  Chevrolet
#
#             Model
# 492234  Silverado
# ======= Repeated VIN KNAFU6A27A5241492
#         Price  Year  Mileage       City State                Vin Make    Model
# 914949   9995  2010    81240  Las Vegas    NV  KNAFU6A27A5241492  Kia  ForteEX
# ======= Repeated VIN 5NPEB4AC7BH043224
#         Price  Year  Mileage          City State                Vin     Make  \
# 384613   7991  2011    82438  Garden Grove    CA  5NPEB4AC7BH043224  Hyundai
#
#             Model
# 384613  Sonata4dr
# ======= Repeated VIN 5UXWX9C59E0D26826
#         Price  Year  Mileage     City State                Vin Make  \
# 168333  22995  2014    44937  Burbank    CA  5UXWX9C59E0D26826  BMW
#
#               Model
# 168333  X3xDrive28i
# ======= Repeated VIN 1C6RD6LT3CS324516
#         Price  Year  Mileage     City State                Vin Make    Model
# 298851  20995  2012    67535  Concord    CA  1C6RD6LT3CS324516  Ram  15002WD
# ======= Repeated VIN 3FAHP0GAXCR419917
#         Price  Year  Mileage        City State                Vin  Make  \
# 616202  10795  2012    97798  Miamisburg    OH  3FAHP0GAXCR419917  Ford
#
#           Model
# 616202  FusionS
# ======= Repeated VIN 3GCUKREC0EG311904
#         Price  Year  Mileage   City State                Vin       Make  \
# 521515  39522  2014    13768  Nampa    ID  3GCUKREC0EG311904  Chevrolet
#
#             Model
# 521515  Silverado
# ======= Repeated VIN 1D8GU58K87W611389
#        Price  Year  Mileage      City State                Vin   Make  \
# 74743  11595  2007    80648  Highland    IN  1D8GU58K87W611389  Dodge
#
#           Model
# 74743  Nitro4WD
# ======= Repeated VIN 2T1BURHE3GC691820
#          Price  Year  Mileage    City State                Vin    Make  \
# 1135905  15991  2016    13422  Dothan    AL  2T1BURHE3GC691820  Toyota
#
#              Model
# 1135905  CorollaLE
# ======= Repeated VIN 1GCVKSEC1EZ394917
#         Price  Year  Mileage      City State                Vin       Make  \
# 512401  30790  2014    46317  Kennesaw    GA  1GCVKSEC1EZ394917  Chevrolet
#
#             Model
# 512401  Silverado
# ======= Repeated VIN 1C4NJRFB1ED904908
#         Price  Year  Mileage      City State                Vin  Make  \
# 851872  13882  2014    35663  Waukesha    WI  1C4NJRFB1ED904908  Jeep
#
#                   Model
# 851872  PatriotLatitude
# ======= Repeated VIN 3N1CE2CP3GL371219
#         Price  Year  Mileage       City State                Vin    Make  \
# 291754  16991  2016     6545  Oak Ridge    TN  3N1CE2CP3GL371219  Nissan
#
#         Model
# 291754  Versa
# ======= Repeated VIN 1N4AA5AP6CC850671
#          Price  Year  Mileage         City State                Vin    Make  \
# 1018806  13988  2012    64137  San Antonio    TX  1N4AA5AP6CC850671  Nissan
#
#              Model
# 1018806  Maxima4dr
# ======= Repeated VIN 2C4RDGCG3HR691409
#        Price  Year  Mileage          City State                Vin   Make  \
# 69551  23500  2017    24269  Grand Rapids    MI  2C4RDGCG3HR691409  Dodge
#
#        Model
# 69551  Grand
# ======= Repeated VIN 1FMCU9GX4GUB62298
#         Price  Year  Mileage     City State                Vin  Make     Model
# 620721  20500  2016    14590  Bel Air    MD  1FMCU9GX4GUB62298  Ford  EscapeSE
# ======= Repeated VIN 1C4BJWDG1EL309238
#         Price  Year  Mileage        City State                Vin  Make  \
# 875645  25990  2014    26890  Shrewsbury    NJ  1C4BJWDG1EL309238  Jeep
#
#            Model
# 875645  Wrangler
# ======= Repeated VIN WDBTJ56J66F170598
#         Price  Year  Mileage    City State                Vin           Make  \
# 253241   5730  2006   167598  Buford    GA  WDBTJ56J66F170598  Mercedes-Benz
#
#                   Model
# 253241  CLK-ClassCLK350
# ======= Repeated VIN 4T4BF3EKXAR011053
#          Price  Year  Mileage        City State                Vin    Make  \
# 1128077  10409  2010    85645  Naperville    IL  4T4BF3EKXAR011053  Toyota
#
#              Model
# 1128077  CamryBase
# ======= Repeated VIN 3C4PDCAB5ET270520
#        Price  Year  Mileage      City State                Vin   Make  \
# 79173  12999  2014    65488  Puyallup    WA  3C4PDCAB5ET270520  Dodge
#
#            Model
# 79173  JourneySE
# ======= Repeated VIN 1FADP3L92EL200110
#         Price  Year  Mileage     City State                Vin  Make    Model
# 628657  17994  2014    37649  Seattle    WA  1FADP3L92EL200110  Ford  FocusST
# ======= Repeated VIN 3GTU2NECXGG109213
#        Price  Year  Mileage    City State                Vin Make   Model
# 11183  37800  2016    34007  Linden    NJ  3GTU2NECXGG109213  GMC  Sierra
# ======= Repeated VIN 3GTU2WEC5FG411335
#         Price  Year  Mileage   City State                Vin Make   Model
# 730307  36888  2015    55426  Baird    TX  3GTU2WEC5FG411335  GMC  Sierra
# ======= Repeated VIN 2G1WF5E36D1265968
#         Price  Year  Mileage     City State                Vin       Make  \
# 120068  13795  2013    34857  Augusta    GA  2G1WF5E36D1265968  Chevrolet
#
#            Model
# 120068  ImpalaLS
# ======= Repeated VIN 1GCNCPEX5BZ199623
#         Price  Year  Mileage             City State                Vin  \
# 125660  10995  2011    32322  North Attleboro    MA  1GCNCPEX5BZ199623
#
#              Make      Model
# 125660  Chevrolet  Silverado
# ======= Repeated VIN 2T1BU4EE7BC565962
#         Price  Year  Mileage    City State                Vin    Make  \
# 322766   9595  2011    93354  Fresno    CA  2T1BU4EE7BC565962  Toyota
#
#              Model
# 322766  Corolla4dr
# ======= Repeated VIN 1FA6P8TH3H5281897
#        Price  Year  Mileage     City State                Vin  Make  \
# 48746  24596  2017    16033  Atlanta    GA  1FA6P8TH3H5281897  Ford
#
#                  Model
# 48746  MustangEcoBoost

# %% [markdown]
# <span id="up"></span>
#
# ##### 3.5.1.2.3 Upper Case the other Columns:

# %%
df_full["Model"] = df_full["Model"].apply(upper_states)

# %%
df_full["Model"].value_counts()
# Out:
# SILVERADO    35769
# GRAND        25347
# ALTIMA2.5    16823
# SIERRA       16318
# ACCORD       14865
#              ...
# MKS              1
# MKSBASE          1
# MKX              1
# LFALFA           1
# COBALTSS         1
# Name: Model, Length: 3074, dtype: int64

# %% [markdown]
# It Seams that there was a duplicate model with the different representations in the data.

# %%
df_full["Make"] = df_full["Make"].apply(upper_states)
df_full["City"] = df_full["City"].apply(upper_states)

# %%
df_full["Make"].value_counts()
# Out:
# FORD             161042
# CHEVROLET        149571
# TOYOTA           116578
# NISSAN            98533
# HONDA             76497
# JEEP              60242
# HYUNDAI           54605
# DODGE             50247
# KIA               42808
# GMC               42713
# MERCEDES-BENZ     38094
# VOLKSWAGEN        33220
# BMW               32401
# LEXUS             29729
# RAM               24603
# CHRYSLER          23802
# SUBARU            23720
# CADILLAC          21883
# MAZDA             19833
# BUICK             18132
# INFINITI          17725
# AUDI              12613
# ACURA             11015
# LINCOLN           10045
# VOLVO              7323
# MINI               6223
# MITSUBISHI         5910
# LAND               5842
# PORSCHE            5783
# SCION              4381
# JAGUAR             3113
# FIAT               2613
# PONTIAC            2538
# MERCURY            1584
# SATURN             1429
# MASERATI           1379
# HUMMER             1322
# SMART               982
# SUZUKI              482
# FERRARI             420
# SAAB                367
# BENTLEY             367
# TESLA               352
# GENESIS             209
# OLDSMOBILE          162
# ASTON               149
# LAMBORGHINI         141
# ROLLS-ROYCE         108
# ISUZU               101
# PLYMOUTH             70
# MCLAREN              64
# LOTUS                49
# ALFA                 44
# FISKER               25
# AM                   19
# FREIGHTLINER         13
# MAYBACH              11
# GEO                   3
# Name: Make, dtype: int64

# %% [markdown]
# Also here there was some entries that was duplicated.

# %%
df_full["City"].value_counts()
# Out:
# HOUSTON         20788
# SAN ANTONIO     11683
# LOUISVILLE       9398
# AUSTIN           8516
# JACKSONVILLE     8189
#                 ...
# ARMONA              4
# BRICK TOWN          4
# LOS BANOS           4
# ROYSTON             2
# EMINENCE            1
# Name: City, Length: 2446, dtype: int64

# %% [markdown]
# Also the same results here.

# %% [markdown]
# <span id="divi"></span>
#
# ##### 3.5.1.2.4 Dividing into New and old car:
# To study if there is any differences in the data as it's expected to have new manufacturers and also relatively high prices for new cars, and also invistigate the large number of cities.

# %%
df_full["City"].value_counts()[df_full["City"].value_counts() < 100]
# Out:
# WHITTIER         99
# BARNEVELD        99
# COEUR D'ALENE    99
# LA MESA          99
# SCARBOROUGH      99
#                  ..
# ARMONA            4
# BRICK TOWN        4
# LOS BANOS         4
# ROYSTON           2
# EMINENCE          1
# Name: City, Length: 682, dtype: int64

# %% [markdown]
# It appers that there are 682 City that appears less than 100 times in the data set.

# %%
df_full[df_full["Year"] < 2006].shape
# Out:
# (48428, 8)

# %%
df_full.shape
# Out:
# (1223229, 8)

# %%
# Cars that manufacutred before 2006
df_old = df_full[df_full["Year"] < 2006]

# %%
# Cars that manufacutred bafter 2006
df_new = df_full[df_full["Year"] >= 2006]

# %%
df_old.shape
# Out:
# (48428, 8)

# %%
df_new.shape
# Out:
# (1174801, 8)

# %% [markdown]
# It appears that the old cas represents a very small portion of the data, so we will divide them and study each one, now we willstudy if the distribution of the offered cars differs fromm the new and old ones according to the city of the seller?

# %% [markdown]
# <span id="exc"></span>
#
# ##### 3.5.1.2.5 Excluding all cars with useagevery small as they cannot considered as used cars:

# %%
df_full.drop(df_full[df_full["Mileage"] < 10].index, inplace = True)

# %%
df_full = df_full.reset_index().drop(columns = ["index"])

# %%
df_full
# Out:
#          Price  Year  Mileage            City State                Vin  \
# 0        16472  2015    18681  JEFFERSON CITY    MO  KL4CJBSBXFB267643
# 1        15749  2015    27592        HIGHLAND    IN  KL4CJASB5FB245057
# 2        16998  2015    13650           BOONE    NC  KL4CJCSB0FB264921
# 3        15777  2015    25195     NEW ORLEANS    LA  KL4CJASB4FB217542
# 4        16784  2015    22800       LAS VEGAS    NV  KL4CJBSB3FB166881
# ...        ...   ...      ...             ...   ...                ...
# 1221967  16490  2013    28969        CHEHALIS    WA  WVWHV7AJXDW068975
# 1221968  14990  2013    61299         ANSONIA    CT  WVWHV7AJ2DW134371
# 1221969  17909  2013    36275       CHARLOTTE    NC  WVWHV7AJ0DW009210
# 1221970  18995  2013    43079         MISSION    TX  WVWHV7AJ5DW082797
# 1221971  16551  2013    68107          AUSTIN    TX  WVWHV7AJ4DW123050
#
#                Make              Model
# 0             BUICK  ENCORECONVENIENCE
# 1             BUICK          ENCOREFWD
# 2             BUICK      ENCORELEATHER
# 3             BUICK          ENCOREFWD
# 4             BUICK  ENCORECONVENIENCE
# ...             ...                ...
# 1221967  VOLKSWAGEN         GTI4-DOOR,
# 1221968  VOLKSWAGEN         GTI4-DOOR,
# 1221969  VOLKSWAGEN         GTI4-DOOR,
# 1221970  VOLKSWAGEN         GTI4-DOOR,
# 1221971  VOLKSWAGEN         GTI4-DOOR,
#
# [1221972 rows x 8 columns]

# %% [markdown]
# <span id="vin2"></span>
#
# ##### 3.5.1.2.6 Removing Vin column:
# As this column has a very high cardinality, so this will not affect the anlaysis.

# %%
df_full.drop(columns = ["Vin"], inplace = True)

# %% [markdown]
# <span id="feat"> </span>
# # 4. Feature Engineering:

# %% [markdown]
# <span id="feat1"> </span>
#
# ## 4.1 Usage Level:

# %% [markdown]
# From the distribution of the mileage column, we can see that the first quantile is arround 25k Mile, and the third quantile is arround 80K Mile, so we can have a new feature that identifies the level of car usage as a function of mileage made by the car as follows:
# - Mileage < 25K mile ==> Low usage
# - Mileage between 25K and 80K ==> Moderate usage
# - Mileage larger than that ==> High usage.

# %%
def get_mile_range(mileage):
    if mileage < 25000:
        return "Low"
    elif (25000 <= mileage) and (mileage < 80000 ):
        return "Medium"
    else:
        return "High"

# %%
df_full["Usage_level"] = df_full["Mileage"].apply(get_mile_range)

# %%
df_full
# Out:
#          Price  Year  Mileage            City State        Make  \
# 0        16472  2015    18681  JEFFERSON CITY    MO       BUICK
# 1        15749  2015    27592        HIGHLAND    IN       BUICK
# 2        16998  2015    13650           BOONE    NC       BUICK
# 3        15777  2015    25195     NEW ORLEANS    LA       BUICK
# 4        16784  2015    22800       LAS VEGAS    NV       BUICK
# ...        ...   ...      ...             ...   ...         ...
# 1221967  16490  2013    28969        CHEHALIS    WA  VOLKSWAGEN
# 1221968  14990  2013    61299         ANSONIA    CT  VOLKSWAGEN
# 1221969  17909  2013    36275       CHARLOTTE    NC  VOLKSWAGEN
# 1221970  18995  2013    43079         MISSION    TX  VOLKSWAGEN
# 1221971  16551  2013    68107          AUSTIN    TX  VOLKSWAGEN
#
#                      Model Usage_level
# 0        ENCORECONVENIENCE         Low
# 1                ENCOREFWD      Medium
# 2            ENCORELEATHER         Low
# 3                ENCOREFWD      Medium
# 4        ENCORECONVENIENCE         Low
# ...                    ...         ...
# 1221967         GTI4-DOOR,      Medium
# 1221968         GTI4-DOOR,      Medium
# 1221969         GTI4-DOOR,      Medium
# 1221970         GTI4-DOOR,      Medium
# 1221971         GTI4-DOOR,      Medium
#
# [1221972 rows x 8 columns]

# %% [markdown]
# <span id="feat2"> </span>
#
# ## 4.2 USA Main Cities:
#
# As A result we can see effects of the cities in prices, so we will add one column to identifiy city importance, by importance here we mean the most crowded cities as follows:
# - Cities > 1Million people in population with a high importance
# - Cities between 700k and 1Million people with a Medium Importance
# - Cities <700K People with low importance.

# %%
def city_importance(city):
    important_cities = ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia",
                        "San Antonio", "San Diego", "Dallas", "San Jose"]
    Midium_cities = ["Austin", "Jacksonville", "Fort Worth", "Columbus", "Charlotte", "San Francisco",
                     "Indianapolis", "Seattle", "Denver", "Washington"]
    important_cities = [c.upper() for c in important_cities]
    Midium_cities = [c.upper() for c in Midium_cities]
    if city in important_cities:
        return "High"
    elif city in Midium_cities:
        return "Medium"
    else:
        return "Low"

df_full["City_imporatnce"] = df_full["City"].apply(city_importance)

# %%
df_full
# Out:
#          Price  Year  Mileage            City State        Make  \
# 0        16472  2015    18681  JEFFERSON CITY    MO       BUICK
# 1        15749  2015    27592        HIGHLAND    IN       BUICK
# 2        16998  2015    13650           BOONE    NC       BUICK
# 3        15777  2015    25195     NEW ORLEANS    LA       BUICK
# 4        16784  2015    22800       LAS VEGAS    NV       BUICK
# ...        ...   ...      ...             ...   ...         ...
# 1221967  16490  2013    28969        CHEHALIS    WA  VOLKSWAGEN
# 1221968  14990  2013    61299         ANSONIA    CT  VOLKSWAGEN
# 1221969  17909  2013    36275       CHARLOTTE    NC  VOLKSWAGEN
# 1221970  18995  2013    43079         MISSION    TX  VOLKSWAGEN
# 1221971  16551  2013    68107          AUSTIN    TX  VOLKSWAGEN
#
#                      Model Usage_level City_imporatnce
# 0        ENCORECONVENIENCE         Low             Low
# 1                ENCOREFWD      Medium             Low
# 2            ENCORELEATHER         Low             Low
# 3                ENCOREFWD      Medium             Low
# 4        ENCORECONVENIENCE         Low             Low
# ...                    ...         ...             ...
# 1221967         GTI4-DOOR,      Medium             Low
# 1221968         GTI4-DOOR,      Medium             Low
# 1221969         GTI4-DOOR,      Medium          Medium
# 1221970         GTI4-DOOR,      Medium             Low
# 1221971         GTI4-DOOR,      Medium          Medium
#
# [1221972 rows x 9 columns]

# %% [markdown]
# <span id="feat3"> </span>
#
# ## 4.3 Distributions of the added columns:

# %%
df_full["Usage_level"].value_counts()
# Out:
# Medium    641151
# Low       324645
# High      256176
# Name: Usage_level, dtype: int64

# %%
#Plotting Usage Level:
i = "Usage_level"
plt.figure(figsize = (10,10))
plt.title(f"Histogram of values for column {i}")
sns.countplot(x= df_full[i])
plt.ylim(top = np.max(r[0]) + 10)
plt.show()

# %% [markdown]
# As we can see the most usage appears in the medium as we want.

# %%
#Plotting Usage Level:
i = "City_imporatnce"
plt.figure(figsize = (10,10))
plt.title(f"Histogram of values for column {i}")
sns.countplot(x= df_full[i])
plt.ylim(top = np.max(r[0]) + 600000)
plt.show()

# %% [markdown]
# <span id="answer"></span>
#
# # 5. Answering Questions:

# %% [markdown]
# <span id="q1"></span>
#
# ## 5.1 Is the distribution of the offered cars differs from the new and old ones according to the city of the seller?

# %%
#For New Cars:
new_cities = df_new.City.value_counts()[:10]

# %%
new_cities.at["Other_cities"] = df_new.City.value_counts()[10:].sum()

# %%
new_cities
# Out:
# HOUSTON               20112
# SAN ANTONIO           11457
# LOUISVILLE             9248
# AUSTIN                 8285
# JACKSONVILLE           7812
# MIAMI                  7772
# ORLANDO                7600
# COLORADO SPRINGS       6732
# PHILADELPHIA           6656
# RALEIGH                6585
# Other_cities        1082542
# Name: City, dtype: int64

# %%
#for old cars:
df_old.City.value_counts()[:10]
# Out:
# HOUSTON             676
# SACRAMENTO          497
# RALEIGH             490
# CHANTILLY           446
# COLORADO SPRINGS    446
# PHOENIX             417
# VIRGINIA BEACH      395
# TUCSON              379
# JACKSONVILLE        377
# LONGMONT            333
# Name: City, dtype: int64

# %%
old_cities = df_old.City.value_counts()[:10]
old_cities.at["Other_cities"] = df_old.City.value_counts()[10:].sum()

# %%
old_cities
# Out:
# HOUSTON               676
# SACRAMENTO            497
# RALEIGH               490
# CHANTILLY             446
# COLORADO SPRINGS      446
# PHOENIX               417
# VIRGINIA BEACH        395
# TUCSON                379
# JACKSONVILLE          377
# LONGMONT              333
# Other_cities        43972
# Name: City, dtype: int64

# %%
plt.title("Old Cars Cities' Distribution", pad= 120, fontsize = 25)
plt.pie(old_cities[:-1], labels = old_cities.index[:-1], shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %%
plt.title("New Cars Cities' Distribution", pad= 120, fontsize = 25)

plt.pie(new_cities[:-1], labels = new_cities.index[:-1], shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %% [markdown]
# It Appears that the `Houston` City has the most offerings all the time, but Cities like `SAN ANTONIO` and `LOUISVILLE` has more new cars' offerings than the old cars' and cities like `SACRAMENTO`, `RALEIGH` and `CHANTILLY` has more older cars, so if yo want to by a relatively new car you can search in `Houston`, `SAN ANTONIO` and `LOUISVILLE` cities.

# %% [markdown]
# <span id="q2"></span>
#
# ## 5.2 Is the distribution of the offered cars differs from the new and old ones according to the State of the seller?

# %%
old_states = df_old["State"].value_counts()[:10]

# %%
new_states = df_new["State"].value_counts()[:10]

# %%
old_states
# Out:
#  CA    4353
#  TX    3970
#  FL    3360
#  VA    3263
#  IL    2770
#  CO    2476
#  WA    2476
#  NC    2092
#  GA    1869
#  OH    1715
# Name: State, dtype: int64

# %%
new_states
# Out:
#  TX    136383
#  CA    110831
#  FL    104486
#  GA     53959
#  IL     52182
#  NC     50776
#  VA     46036
#  PA     39012
#  NY     37648
#  NJ     36779
# Name: State, dtype: int64

# %%
plt.title("Old Cars States' Distribution", pad= 70, fontsize = 25)
plt.pie(old_states, labels = old_states.index, shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %%
plt.title("new Cars States' Distribution", pad= 70, fontsize = 25)
plt.pie(new_states, labels = new_states.index, shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %% [markdown]
# It Seams that `California`, `Texas` and `Florida` state has more offerings all the time, but other cities' may differ so if you want to buy a relatively new cars, it's supposed that you won't go to any of these cities but you can go to `Georgia` and `Illinois` States, but if you are not sure about the car it will be a good idea to go to on of the first three states as they have more offerings.

# %% [markdown]
# <span id="q3"></span>
#
# ## 5.3 Is There is any differences in the Price between the old and the new cars?

# %%
df_old.Price.mean()
# Out:
# 8563.823511191873

# %%
df_new.Price.mean()
# Out:
# 21617.102851461652

# %% [markdown]
# Yes the new cars have more than 2.5X the old car prices on average.

# %% [markdown]
# <span id="q4"></span>
#
# ## 5.4 Is The Price of the car affected by the State of the seller ?

# %%
df_new_states = df_new.groupby("State")["Price"].mean().sort_values(ascending=False)

# %%
df_new_states
# Out:
# State
#  SD    25539.087043
#  WY    25505.100758
#  MT    25311.346720
#  MS    23839.748113
#  TX    23631.399705
#  AR    23375.046579
#  WV    23115.340102
#  LA    23065.676549
#  NM    22910.749234
#  NE    22871.408670
#  WA    22553.997582
#  OR    22494.054904
#  AL    22371.723578
#  ME    22304.923643
#  NY    22191.483425
#  IA    22148.719358
#  RI    22085.647288
#  CO    22016.830576
#  UT    22015.514333
#  NJ    21849.784823
#  OK    21736.392740
#  PA    21671.264765
#  CA    21656.504227
#  DE    21625.766180
#  ID    21614.252457
#  NC    21591.994151
#  GA    21576.441131
#  TN    21567.729009
#  IL    21558.383312
#  MA    21530.602704
#  AK    21430.593007
#  MN    21389.231387
#  ND    21325.249567
#  SC    21163.728682
#  MO    21147.161486
#  FL    21144.711311
#  NH    21122.423239
#  WI    20958.575969
#  KS    20925.357250
#  NV    20843.730312
#  MD    20713.413637
#  KY    20575.842329
#  AZ    20407.044562
#  IN    20240.088340
#  VA    19556.836020
#  MI    19308.810883
#  OH    19117.416486
#  CT    19048.625341
#  VT    18940.931590
#  HI    18336.326575
#  DC    13656.733333
# Name: Price, dtype: float64

# %%
df_old_states = df_old.groupby("State")["Price"].mean().sort_values(ascending=False)

# %%
df_old_states
# Out:
# State
#  WV    12248.351351
#  RI    11921.965517
#  NM    11313.309645
#  NV    11100.329975
#  AK    10606.016129
#  CA    10486.478521
#  OR    10212.995713
#  AZ    10208.562539
#  DC    10093.692308
#  SD     9646.951049
#  NC     9476.688337
#  MD     9356.385586
#  WY     9250.017544
#  MA     9143.640000
#  MT     9109.453947
#  MO     9071.096308
#  DE     9021.909091
#  NY     9001.116327
#  TX     8963.358438
#  CO     8947.119548
#  MS     8945.576744
#  MN     8926.448584
#  WA     8905.670840
#  GA     8803.714286
#  AL     8798.901042
#  CT     8796.198708
#  TN     8545.647766
#  SC     8501.227273
#  ID     8406.324390
#  ME     8328.914286
#  AR     8120.236287
#  HI     8073.480769
#  FL     8068.050000
#  VT     8057.441860
#  ND     8049.389381
#  NE     7805.419087
#  IL     7615.244043
#  NJ     7590.811728
#  MI     7573.677758
#  OK     7568.457023
#  VA     7544.057003
#  LA     7517.402214
#  KY     7407.903282
#  KS     7350.257541
#  IA     7316.930091
#  PA     7294.066491
#  UT     7238.962190
#  WI     7156.883478
#  IN     6771.028571
#  NH     6739.792271
#  OH     6735.039067
# Name: Price, dtype: float64

# %% [markdown]
# Yes the State of the car affect the price this is different in the old cars.

# %% [markdown]
# <span id="q5"></span>
#
# ## 5.5 How the Prices of the cars are changed according to the year of manufacturing?

# %%
df_new_grouped = df_new.groupby("State")
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("New Cars' Prices", fontsize = 20)
axs.set_xlabel("Year")
axs.set_ylabel("Mean Price of the cars")
for group in df_new_grouped.groups:
#     print(group)
    if group in df_new_states.index[:5]:
        df_state = df_new_grouped.get_group(group)
        df_state_years = df_state.groupby("Year")["Price"].mean()
        axs.plot(df_state_years, label = group)
plt.legend()
plt.show()

# %% [markdown]
# - `Wyoming`, `South Dakota` have a relatively high prices over cars but it seams that it has not any offerings after 2017.
# - we can see an intersting behavior of `Texas` state, where the older cars has relatively smal prices bu for most recent cars `2018` it has the largest price.
# - finally the prices of the car have been doubled 4 times if it has has been manufactured recently.

# %%
df_old_grouped = df_old.groupby("State")
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("Old Cars' Prices", fontsize = 20)
axs.set_xlabel("Year")
axs.set_ylabel("Mean Price of the cars")
for group in df_old_grouped.groups:
    if group in df_old_states.index[:5]:
        df_state = df_old_grouped.get_group(group)
        df_state_years = df_state.groupby("Year")["Price"].mean()
        axs.plot(df_state_years, label = group)
plt.legend()
plt.show()

# %% [markdown]
# - Here in the older cars there is a relatively constant prices for the cars.
# - For `Rhode Island` and `West Virginia` there are no offerings before `1999`.

# %% [markdown]
# <span id="q6"></span>
#
# ## 5.6 Is There is any relation between the Year and the Mileage?

# %%
df_old_grouped = df_old.groupby("State")
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("Old Cars' Mileages", fontsize = 20)
axs.set_xlabel("Year")
axs.set_ylabel("Mean Mileage of the cars")
for group in df_old_grouped.groups:
    if group in df_old_states.index[:5]:
        df_state = df_old_grouped.get_group(group)
        df_state_years = df_state.groupby("Year")["Mileage"].mean()
        axs.plot(df_state_years, label = group)
plt.legend()
plt.show()

# %% [markdown]
# - For Old Cars it appears that there are relatively smally decreasing trend in the Usage.
# - The `Rhode Island` State has the lowes milage for older cars, so if you want to buy an old car bu not used very much you can search in this state.

# %%
df_new_grouped = df_new.groupby("State")
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("New Cars' Usage", fontsize = 20)
axs.set_xlabel("Year")
axs.set_ylabel("Mean Usage of the cars")
for group in df_new_grouped.groups:
    if group in df_new_states.index[:5]:
        df_state = df_new_grouped.get_group(group)
        df_state_years = df_state.groupby("Year")["Mileage"].mean()
        axs.plot(df_state_years, label = group)
plt.legend()
plt.show()

# %% [markdown]
# - For new cars, as expected the there is high decreasing trend in the usage campared to older ones, and there is no big difference in the usage accross these states.

# %% [markdown]
# <span id="q7"></span>
#
# ##  5.7 What is the distribution of the cars in the market?

# %%
df_new_makers = df_new.groupby("Make")
df_old_makers = df_old.groupby("Make")

# %%
new_makers = df_new["Make"].value_counts()[:10]
old_makers = df_old["Make"].value_counts()[:10]

# %%
plt.title("New Car Makers' Distribution", pad= 120, fontsize = 25)
plt.pie(new_makers, labels = new_makers.index, shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %% [markdown]
# - For New Cars, it appears that `FORD`, `CHEVROLET`, `TOYOTA` and `NISSAN` occupies more than have the distribution of the most frequent brands.

# %%
plt.title("Old Car Makers' Distribution", pad= 120, fontsize = 25)
plt.pie(old_makers, labels = old_makers.index, shadow = True, radius = 1.5, 
       rotatelabels= True)
plt.show()

# %% [markdown]
# - For older cars, also `FORD`, `CHEVROLET` and `TOYOTA` are old brands that are well established, but `NISSAN` Was a realtively new one, and `HONDA` took its place.
# - Alse Here we can see that there are brands that was not in the new distribution, like `MERCEDES-BENZ` which may have two differnt meanings, the first is that:
#     - `MERCEDES-BENZ` cars' are very good cars so their buyers of the new models are very loyal to them so they won't sell it.
#     - `MERCEDES-BENZ` brand has been died in the new era, and this is not applicable.

# %% [markdown]
# <span id="q8"></span>
#
# ## 5.8 How the Price of a certain brand cars' changes according the year of manufacturing?

# %%
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("Average price per brand over time")
for maker in new_makers.index:
    df_maker = df_new_makers.get_group(maker)
    df_maker_timeline = df_maker.groupby("Year")["Price"].mean()
    axs.plot(df_maker_timeline, label = maker)
plt.legend()
plt.show()

# %% [markdown]
# - For New Cars, it seams that `GMC` brand has he highest prices among different ages of cars.
# - For `JEEP` Brand it seams that the newer cars doesn't have the same value of the older one, it seams it's decreasing campared to the other brands.

# %%
fig, axs = plt.subplots(1, figsize = (10,5))
axs.set_title("Average price per brand over time")
for maker in old_makers.index:
    df_maker = df_old_makers.get_group(maker)
    df_maker_timeline = df_maker.groupby("Year")["Price"].mean()
    axs.plot(df_maker_timeline, label = maker)
plt.legend()
plt.show()

# %% [markdown]
# - For Old Cars, `HONDA` is the lowest prices among all ages.
# - `DODGE` Cars' prices has a increasing trend among all ages of the cars.
# - `GMC` saves its place also in the old cars market.

# %% [markdown]
# <span id="q9"></span>
#
# ## 5.9 Is there is any relationship between Mileage, Year and Price?

# %%
import seaborn as sns

# %%
plt.title("Correlation for new cars")
dataplot = sns.heatmap(df_new.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# - For New Cars, it appears that the price has a positive correlation between the price and the year of manufacturing and this means that as we saw befoer, newer cars has higher prices.
# - The Mileage here has a negative correlation with the Price which means that if the car has been used ver much then this will affect its price negatively.
# - The realtion between Year and Milage has a negative correlation, so newer cars used less than the older one and this is the expected behavior.

# %%
plt.title("Correlation for old cars")
dataplot = sns.heatmap(df_old.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# - For old cars, the negative correlation of the mileage with the price is the same.
# - But here the affect of the Year is very small (<1%) so it is so effective.

# %% [markdown]
# ## 5.10 What is the effect of city importance?

# %%
df_grouped = df_full.groupby("City_imporatnce")["Price"].mean()

# %%
df_grouped
# Out:
# City_imporatnce
# High      22704.041736
# Low       20974.012707
# Medium    21657.282948
# Name: Price, dtype: float64

# %%
plt.figure(figsize = (10,10))
plt.title(f"Mean Price Per City importance")
plt.bar(x = df_grouped.index, height= df_grouped)
plt.show()

# %% [markdown]
# Althoght the count of low important cities is the argest, it has the lowes price which means that the price is affected by the population of the city of the seller.

# %% [markdown]
# <span id="div2"></span>
#
# # 6. Dividing Data:

# %%
from sklearn.model_selection import train_test_split

# %%
# Cars that manufacutred before 2006
df_old = df_full[df_full["Year"] < 2006]
# Cars that manufacutred bafter 2006
df_new = df_full[df_full["Year"] >= 2006]

# %%
#For new Dataset:
X = df_new.drop(columns = ["Price"])
Y = df_new.Price
train_new, test_new, y_train_new, y_test_new = train_test_split(X, Y, test_size = 0.1, shuffle= True)

# %%
train_new.to_csv("new_data/train_new_data.csv", index = False)
y_train_new.to_csv("new_data/train_new_taget.csv", index = False)
test_new.to_csv("new_data/test_new_data.csv", index = False)
y_test_new.to_csv("new_data/test_new_target.csv", index = False)

# %%
# For Old Dataset:
X = df_old.drop(columns = ["Price"])
Y = df_old.Price
train_old, test_old, y_train_old, y_test_old = train_test_split(X, Y, test_size = 0.1, shuffle= True)

# %%
train_old.to_csv("new_data/train_old_data.csv", index = False)
y_train_old.to_csv("new_data/train_old_taget.csv", index = False)
test_old.to_csv("new_data/test_old_data.csv", index = False)
y_test_old.to_csv("new_data/test_old_target.csv", index = False)

# %%
train_new
# Out:
#          Year  Mileage               City State           Make  \
# 979963   2017     5921           FREEHOLD    NJ  MERCEDES-BENZ
# 1065109  2015    45928              TEMPE    AZ         NISSAN
# 857448   2008   169536  HASBROUCK HEIGHTS    NJ           JEEP
# 650268   2009    99601      BENNETTSVILLE    SC           FORD
# 547514   2016    26160   SARATOGA SPRINGS    NY       CHRYSLER
# ...       ...      ...                ...   ...            ...
# 120444   2007   185000           FOX LAKE    IL      CHEVROLET
# 58840    2014    51361      HARRISONVILLE    MO           FORD
# 414588   2014    32903           COLUMBUS    OH          BUICK
# 874159   2016    20002           LAKEWOOD    NJ           JEEP
# 436179   2015    41054            GREELEY    CO      CHEVROLET
#
#                      Model Usage_level City_imporatnce
# 979963            C-CLASSC         Low             Low
# 1065109          GT-RBLACK      Medium             Low
# 857448      PATRIOTLIMITED        High             Low
# 650268           FUSION4DR        High             Low
# 547514             300300C      Medium             Low
# ...                    ...         ...             ...
# 120444           MALIBU4DR        High             Low
# 58840             ESCAPESE      Medium             Low
# 414588   VERANOCONVENIENCE      Medium          Medium
# 874159            WRANGLER         Low             Low
# 436179           MALIBU1LT      Medium             Low
#
# [1056190 rows x 8 columns]

# %%
train_old
# Out:
#          Year  Mileage            City State           Make          Model  \
# 324525   2004   120662        CHEHALIS    WA         TOYOTA     COROLLA4DR
# 256272   2003    31977          DUBLIN    OH  MERCEDES-BENZ  SL-CLASSSL500
# 1174648  2002   115807         ACWORTH    GA         TOYOTA           LAND
# 1062080  2002   139517  LITHIA SPRINGS    GA         NISSAN      SENTRA4DR
# 339942   2005   152261         LYNWOOD    CA         TOYOTA      TACOMA2WD
# ...       ...      ...             ...   ...            ...            ...
# 643639   2005    43253          STUART    FL           FORD  RANGERREGULAR
# 342889   1998   132440            ROME    GA         TOYOTA      CELICA3DR
# 368533   2005   178918     CHATTANOOGA    TN          HONDA         ACCORD
# 996204   2003   125810        STAFFORD    VA     MITSUBISHI      LANCER4DR
# 516923   2003   178598      POST FALLS    ID      CHEVROLET      SILVERADO
#
#         Usage_level City_imporatnce
# 324525         High             Low
# 256272       Medium             Low
# 1174648        High             Low
# 1062080        High             Low
# 339942         High             Low
# ...             ...             ...
# 643639       Medium             Low
# 342889         High             Low
# 368533         High             Low
# 996204         High             Low
# 516923         High             Low
#
# [43584 rows x 8 columns]
